# %%
# -*- coding: utf-8 -*-

# %%
pip install arelle
# Out:
# Collecting arelle
#   Downloading arelle-2.2.tar.gz (1.9 MB)
#      |████████████████████████████████| 1.9 MB 7.0 MB/s
# Building wheels for collected packages: arelle
#   Building wheel for arelle (setup.py) ... done
#   Created wheel for arelle: filename=arelle-2.2-py3-none-any.whl size=2060307 sha256=c0367475d722acfa1821c38e4364a957bfd474f4881fb42c40be98bdd214e8f1
#   Stored in directory: /root/.cache/pip/wheels/8c/b2/69/919f97f4f77fd85a26e52df16f1763d68cd18210acc9320ad5
# Successfully built arelle
# Installing collected packages: arelle
# Successfully installed arelle-2.2

# %%
pip install isodate
# Out:
# Collecting isodate
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate) (1.15.0)
# Installing collected packages: isodate
# Successfully installed isodate-0.6.0

# %%
from arelle import ModelManager
from arelle import Cntlr
import os
import zipfile
import glob
import pandas as pd

# %%
def make_edinet_info_list(edinetcodedlinfo_filepath):
    edinet_info = pd.read_csv(edinetcodedlinfo_filepath, skiprows=1,
                                 encoding='cp932')
    edinet_info = edinet_info[["ＥＤＩＮＥＴコード", "提出者業種"]]
    edinet_info_list = edinet_info.values.tolist()
    return edinet_info_list

def unzip_file(zip_dir,xbrl_file_expressions):
    zip_files = glob.glob(os.path.join(zip_dir, '*.zip'))

    number_of_zip_lists = len(zip_files)
    print("number_of_zip_lists：", number_of_zip_lists)

    for index, zip_file in enumerate(zip_files):
        print(zip_file, ":", index + 1, "/", number_of_zip_lists)
        with zipfile.ZipFile(zip_file) as zip_f:
            zip_f.extractall(zip_dir)
            zip_f.close()

    xbrl_files = glob.glob(xbrl_file_expressions)
    return xbrl_files

def make_edinet_company_info_list(xbrl_files,edinet_info_list):
    edinet_company_info_list = []
    for index, xbrl_file in enumerate(xbrl_files):
        edinet_code = ""  # EDINETCODE
        filer_name_jp = ""  # 企業名
        industry_code = ""  # 業種
        temporary_workers = ""  # 臨時雇用者数
        net_income = ""  # 当期純利益
        ROE = ""  # 自己資本利益率
        total_assets = ""  # 総資産
        number_of_female_directors = ""  # 女性役員数（人）
        number_of_male_directors = ""  # 男性役員数（人）
        salary_info = ""  # 平均年間給与（円）
        service_years = ""  # 平均勤続年数（年）
        age_years = ""  # 平均年齢（歳）
        number_of_employees = ""  # 従業員数（人）
        company_info_list = []  # 企業情報

        ctrl = Cntlr.Cntlr()
        model_manager = ModelManager.initialize(ctrl)
        model_xbrl = model_manager.load(xbrl_file)

        print(xbrl_file, ":", index + 1, "/", len(xbrl_files))

        for fact in model_xbrl.facts:

            if fact.concept.qname.localName == 'EDINETCodeDEI':
                print("EDINETコード", fact.value)
                edinet_code = fact.value

                for code_name in edinet_info_list:
                    if code_name[0] == edinet_code:
                        print("業種",code_name[1])
                        industry_code = code_name[1]
                        break

            elif fact.concept.qname.localName == 'FilerNameInJapaneseDEI':
                print("企業名", fact.value)
                filer_name_jp = fact.value

            elif fact.concept.qname.localName == 'AverageNumberOfTemporaryWorkers':
                if fact.contextID == 'CurrentYearInstant_NonConsolidatedMember':
                    print("臨時雇用者数", fact.value)
                    temporary_workers = fact.value

            elif fact.concept.qname.localName == 'NetIncomeLossSummaryOfBusinessResults':
                if fact.contextID == 'CurrentYearDuration_NonConsolidatedMember':
                    print("当期純利益", fact.value)
                    net_income = fact.value

            elif fact.concept.qname.localName == 'RateOfReturnOnEquitySummaryOfBusinessResults':
                if fact.contextID == 'CurrentYearDuration_NonConsolidatedMember':
                    print("自己資本利益率", fact.value)
                    ROE = fact.value
            
            elif fact.concept.qname.localName == 'TotalAssetsSummaryOfBusinessResults':
                if fact.contextID == 'CurrentYearInstant_NonConsolidatedMember':
                    print("総資産", fact.value)
                    total_assets = fact.value
            
            elif fact.concept.qname.localName == 'NumberOfFemaleDirectorsAndOtherOfficers':
                if fact.contextID == 'FilingDateInstant':
                    print("女性役員数（人）", fact.value)
                    number_of_female_directors = fact.value
            
            elif fact.concept.qname.localName == 'NumberOfMaleDirectorsAndOtherOfficers':
                if fact.contextID == 'FilingDateInstant':
                    print("男性役員数（人）", fact.value)
                    number_of_male_directors = fact.value

            elif fact.concept.qname.localName == 'AverageAnnualSalaryInformationAboutReportingCompanyInformationAboutEmployees':
                print("平均年間給与（円）", fact.value)
                salary_info = fact.value

            elif fact.concept.qname.localName == 'AverageLengthOfServiceYearsInformationAboutReportingCompanyInformationAboutEmployees':
                print("平均勤続年数（年）", fact.value)
                service_years = fact.value

            elif fact.concept.qname.localName == 'AverageAgeYearsInformationAboutReportingCompanyInformationAboutEmployees':
                print("平均年齢（年）", fact.value)
                age_years = fact.value

            elif fact.concept.qname.localName == 'NumberOfEmployees':
                if fact.contextID == 'CurrentYearInstant_NonConsolidatedMember':
                    print("従業員数（人）", fact.value)
                    number_of_employees = fact.value

        print("")
        company_info_list.append(edinet_code)
        company_info_list.append(filer_name_jp)
        company_info_list.append(industry_code)
        company_info_list.append(net_income)
        company_info_list.append(ROE)
        company_info_list.append(total_assets)
        company_info_list.append(number_of_female_directors)
        company_info_list.append(number_of_male_directors)
        company_info_list.append(temporary_workers)
        company_info_list.append(salary_info)
        company_info_list.append(service_years)
        company_info_list.append(age_years)
        company_info_list.append(number_of_employees)

        edinet_company_info_list.append(company_info_list)

    return edinet_company_info_list

def write_csv_of_employee_info(edinet_company_info_list):

    employee_frame = pd.DataFrame(edinet_company_info_list,
                         columns=['EDINETCODE', '企業名', '業種',  ' 当期純利益', '自己資本利益率', '総資産','女性役員数（人）','男性役員数（人）','臨時雇用者数','平均年間給与（円）', ' 平均勤続年数（年）', '平均年齢（歳）', '従業員数（人）'])

    print(employee_frame)
    employee_frame.to_csv("/content/drive/MyDrive/Graduation Paper Data/total_info_2020q4.csv", encoding='cp932')


def main():
    edinetcodedlinfo_filepath = '/content/drive/MyDrive/Graduation Paper Data/EdinetcodeDlInfo.csv'
    edinet_info_list = make_edinet_info_list(edinetcodedlinfo_filepath)

    zip_dir = '/content/drive/MyDrive/Graduation Paper Data/20201001-20201231'
    xbrl_file_expressions = '/content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/*.xbrl'
    xbrl_files = unzip_file(zip_dir,xbrl_file_expressions)

    edinet_company_info_list = make_edinet_company_info_list(xbrl_files,edinet_info_list)
    print(edinet_company_info_list)

    write_csv_of_employee_info(edinet_company_info_list)
    print("extract finish")

if __name__ == "__main__":
    main()
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 企業名 株式会社一や
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05705-000_2020-07-31_01_2020-10-29.xbrl : 34 / 330
# 当期純利益 1155812000
# 総資産 7293139000
# 自己資本利益率 0.365
# 従業員数（人） 709
# 臨時雇用者数
# 従業員数（人） 709
# 平均年齢（年） 33.2
# 平均勤続年数（年） 7.5
# 平均年間給与（円） 5778067
# 男性役員数（人） 11
# 女性役員数（人）
# EDINETコード E05705
# 業種 情報・通信業
# 企業名 株式会社アイル
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35611-000_2020-07-31_01_2020-10-29.xbrl : 35 / 330
# 当期純利益 13991000
# 総資産 533242000
# 自己資本利益率 0.039
# 従業員数（人） 16
# 臨時雇用者数
# 従業員数（人） 16
# 臨時雇用者数
# 平均年齢（年） 44.5
# 平均勤続年数（年） 3.1
# 平均年間給与（円） 7872000
# 男性役員数（人） 6
# 女性役員数（人） 2
# EDINETコード E35611
# 業種 サービス業
# 企業名 株式会社さくらさくプラス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34999-000_2020-07-31_01_2020-10-29.xbrl : 36 / 330
# 当期純利益 347761000
# 総資産 11281415000
# 自己資本利益率 0.052
# 従業員数（人） 34
# 臨時雇用者数 17
# 従業員数（人） 34
# 臨時雇用者数 17
# 平均年齢（年） 37.4
# 平均勤続年数（年） 2.5
# 平均年間給与（円） 5605000
# 男性役員数（人） 6
# 女性役員数（人） 1
# EDINETコード E34999
# 業種 医薬品
# 企業名 株式会社ステムリム
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34853-000_2020-07-31_01_2020-10-29.xbrl : 37 / 330
# 当期純利益 295726000
# 総資産 2294541000
# 自己資本利益率 0.1711
# 従業員数（人） 58
# 臨時雇用者数 5
# 従業員数（人） 58
# 臨時雇用者数 5
# 平均年齢（年） 29.5
# 平均勤続年数（年） 2.2
# 平均年間給与（円） 6203000
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E34853
# 業種 情報・通信業
# 企業名 株式会社Ｌｉｎｋ－Ｕ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35125-000_2020-07-31_01_2020-10-29.xbrl : 38 / 330
# 当期純利益 -9004000
# 総資産 4912098000
# 自己資本利益率 -0.007
# 従業員数（人） 240
# 臨時雇用者数 356
# 従業員数（人） 240
# 臨時雇用者数 356
# 平均年齢（年） 36.5
# 平均勤続年数（年） 8.0
# 平均年間給与（円） 4139000
# 男性役員数（人） 9
# 女性役員数（人） 4
# EDINETコード E35125
# 業種 小売業
# 企業名 株式会社浜木綿
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E33235-000_2020-07-31_01_2020-10-29.xbrl : 39 / 330
# 当期純利益 132377000
# 総資産 2456505000
# 自己資本利益率 0.075
# 従業員数（人） 28
# 臨時雇用者数 2
# 従業員数（人） 28
# 臨時雇用者数 2
# 平均年齢（年） 35.2
# 平均勤続年数（年） 6.9
# 平均年間給与（円） 4395000
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E33235
# 業種 情報・通信業
# 企業名 株式会社ＳＹＳホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02342-000_2020-07-31_01_2020-10-29.xbrl : 40 / 330
# 当期純利益 447524000
# 総資産 6000087000
# 自己資本利益率 0.122
# 従業員数（人） 123
# 従業員数（人） 123
# 平均年齢（年） 36.2
# 平均勤続年数（年） 6.5
# 平均年間給与（円） 5655563
# 従業員数（人） 123
# 男性役員数（人） 8
# 女性役員数（人） 0
# EDINETコード E02342
# 業種 電気機器
# 企業名 株式会社アルチザネットワークス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E32119-000_2020-07-31_01_2020-10-29.xbrl : 41 / 330
# 当期純利益 -1183382000
# 総資産 12321169000
# 自己資本利益率 -0.398
# 従業員数（人） 454
# 臨時雇用者数 116
# 従業員数（人） 454
# 臨時雇用者数 116
# 平均年齢（年） 27.2
# 平均勤続年数（年） 4.4
# 平均年間給与（円） 4023000
# 従業員数（人） 454
# 臨時雇用者数 116
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E32119
# 業種 サービス業
# 企業名 株式会社ブラス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35028-000_2020-07-31_01_2020-10-29.xbrl : 42 / 330
# 当期純利益 -431740000
# 総資産 2162370000
# 自己資本利益率
# 従業員数（人） 135
# 臨時雇用者数 59
# 従業員数（人） 135
# 臨時雇用者数 59
# 平均年齢（年） 30.7
# 平均勤続年数（年） 1.8
# 平均年間給与（円） 4691000
# 従業員数（人） 135
# 臨時雇用者数 59
# 男性役員数（人） 8
# 女性役員数（人） 2
# EDINETコード E35028
# 業種 不動産業
# 企業名 株式会社ツクルバ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04024-000_2020-07-31_01_2020-10-30.xbrl : 43 / 330
# 当期純利益 212199000
# 総資産 7230369000
# 自己資本利益率 0.103
# 従業員数（人） 31
# 従業員数（人） 31
# 平均年齢（年） 38.2
# 平均勤続年数（年） 6.1
# 平均年間給与（円） 4691000
# 従業員数（人） 31
# 男性役員数（人） 9
# 女性役員数（人） 0
# EDINETコード E04024
# 業種 不動産業
# 企業名 株式会社明豊エンタープライズ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35989-000_2020-07-31_01_2020-10-30.xbrl : 44 / 330
# 当期純利益 83649000
# 総資産 438436000
# 自己資本利益率 0.303
# 従業員数（人） 30
# 臨時雇用者数 2
# 従業員数（人） 30
# 臨時雇用者数 2
# 平均年齢（年） 33.5
# 平均勤続年数（年） 2.7
# 平均年間給与（円） 4518000
# 従業員数（人） 30
# 臨時雇用者数 2
# 男性役員数（人） 8
# 女性役員数（人） 0
# EDINETコード E35989
# 業種 サービス業
# 企業名 株式会社カラダノート
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E32141-000_2020-07-31_01_2020-10-30.xbrl : 45 / 330
# 当期純利益 190688000
# 総資産 2339119000
# 自己資本利益率 0.096
# 従業員数（人） 161
# 臨時雇用者数 44
# 従業員数（人） 161
# 臨時雇用者数 44
# 平均年齢（年） 33.7
# 平均勤続年数（年） 4.0
# 平均年間給与（円） 5729760
# 男性役員数（人） 8
# 女性役員数（人） 1
# EDINETコード E32141
# 業種 情報・通信業
# 企業名 株式会社はてな
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04023-000_2020-07-31_01_2020-10-30.xbrl : 46 / 330
# 当期純利益 3150845000
# 総資産 14532697000
# 自己資本利益率 0.734
# 従業員数（人） 18
# 従業員数（人） 18
# 平均年齢（年） 42.3
# 平均勤続年数（年） 5.1
# 平均年間給与（円） 8415000
# 従業員数（人） 18
# 男性役員数（人） 7
# 女性役員数（人） 0
# EDINETコード E04023
# 業種 不動産業
# 企業名 株式会社アルデプロ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02083-000_2020-07-31_01_2020-10-30.xbrl : 47 / 330
# 当期純利益 -521457000
# 総資産 2407911000
# 自己資本利益率 -0.446
# 従業員数（人） 60
# 臨時雇用者数 11
# 従業員数（人） 60
# 臨時雇用者数 11
# 従業員数（人） 60
# 臨時雇用者数 11
# 平均年齢（年） 51
# 平均勤続年数（年） 16
# 平均年間給与（円） 5038178
# 男性役員数（人） 7
# 女性役員数（人） 1
# EDINETコード E02083
# 業種 電気機器
# 企業名 ウインテスト株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00954-000_2020-07-31_01_2020-10-30.xbrl : 48 / 330
# 当期純利益 1865000000
# 総資産 110968000000
# 自己資本利益率 0.0205
# 従業員数（人） 811
# 臨時雇用者数 197
# EDINETコード E00954
# 業種 医薬品
# 企業名 佐藤製薬株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34322-000_2020-07-31_01_2020-10-30.xbrl : 49 / 330
# 当期純利益 100479000
# 総資産 40981987000
# 自己資本利益率 0.026
# 従業員数（人） 157
# 臨時雇用者数 87
# 従業員数（人） 157
# 臨時雇用者数 87
# 平均年齢（年） 39.5
# 平均勤続年数（年） 3.4
# 平均年間給与（円） 9859000
# 従業員数（人） 157
# 臨時雇用者数 87
# 男性役員数（人） 10
# 女性役員数（人）
# EDINETコード E34322
# 業種 不動産業
# 企業名 株式会社リーガル不動産
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E36046-000_2020-07-31_01_2020-10-30.xbrl : 50 / 330
# 当期純利益 1143455000
# 総資産 6848058000
# 自己資本利益率 1.3021
# 従業員数（人） 85
# 臨時雇用者数 2
# 従業員数（人） 85
# 臨時雇用者数 2
# 平均年齢（年） 38.2
# 平均勤続年数（年） 1.4
# 平均年間給与（円） 5885000
# 従業員数（人） 85
# 臨時雇用者数 2
# 男性役員数（人） 7
# 女性役員数（人） 1
# EDINETコード E36046
# 業種 化学
# 企業名 プレミアアンチエイジング株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E31815-000_2020-07-31_01_2020-10-30.xbrl : 51 / 330
# 当期純利益 -575336000
# 総資産 8911160000
# 自己資本利益率
# 従業員数（人） 53
# 臨時雇用者数 6
# 従業員数（人） 53
# 臨時雇用者数 6
# 平均年齢（年） 36.9
# 平均勤続年数（年） 5.0
# 平均年間給与（円） 4378000
# 男性役員数（人） 8
# 女性役員数（人） 2
# EDINETコード E31815
# 業種 サービス業
# 企業名 株式会社バルニバービ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05327-000_2020-07-31_01_2020-10-30.xbrl : 52 / 330
# 当期純利益 1813512000
# 総資産 16528827000
# 自己資本利益率 0.358
# 従業員数（人） 385
# 臨時雇用者数 715
# 従業員数（人） 385
# 臨時雇用者数 715
# 平均年齢（年） 30.8
# 平均勤続年数（年） 4.3
# 平均年間給与（円） 3444192
# 従業員数（人） 385
# 臨時雇用者数 715
# 男性役員数（人） 13
# 女性役員数（人） 1
# EDINETコード E05327
# 業種 不動産業
# 企業名 日本駐車場開発株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E30454-000_2020-08-31_01_2020-11-12.xbrl : 53 / 330
# 当期純利益 1459506000
# 総資産 20622169000
# 自己資本利益率 0.080
# 従業員数（人） 95
# 臨時雇用者数
# 従業員数（人） 95
# 平均年齢（年） 43.9
# 平均勤続年数（年） 8.0
# 平均年間給与（円） 7391000
# 男性役員数（人） 10
# 女性役員数（人） 1
# EDINETコード E30454
# 業種 情報・通信業
# 企業名 日本ＢＳ放送株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00722-000_2020-08-20_01_2020-11-13.xbrl : 54 / 330
# 当期純利益 139553000
# 総資産 7182800000
# 自己資本利益率 0.0286
# 従業員数（人） 450
# 従業員数（人） 450
# 平均年齢（年） 42.2
# 平均勤続年数（年） 16.01
# 平均年間給与（円） 5211178
# 男性役員数（人） 8
# 女性役員数（人） 0
# EDINETコード E00722
# 業種 その他製品
# 企業名 福島印刷株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02995-000_2020-08-20_01_2020-11-13.xbrl : 55 / 330
# 当期純利益 184125000
# 総資産 4684855000
# 自己資本利益率 0.072
# 従業員数（人） 180
# 臨時雇用者数 70
# 従業員数（人） 180
# 臨時雇用者数 70
# 平均年齢（年） 39.3
# 平均勤続年数（年） 10.7
# 平均年間給与（円） 4320507
# 従業員数（人） 180
# 臨時雇用者数 70
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E02995
# 業種 卸売業
# 企業名 ケイティケイ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35134-000_2020-07-31_01_2020-11-13.xbrl : 56 / 330
# 当期純利益 1160314000
# 総資産 28571445000
# 自己資本利益率 0.0424
# 従業員数（人） 149
# 臨時雇用者数 6
# EDINETコード E35134
# 業種 情報・通信業
# 企業名 株式会社ＳＮＫ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02809-000_2020-08-31_01_2020-11-19.xbrl : 57 / 330
# 当期純利益 3415793000
# 総資産 41451216000
# 自己資本利益率 0.0924
# 従業員数（人） 119
# 従業員数（人） 119
# 平均年齢（年） 40.7
# 平均勤続年数（年） 14.3
# 平均年間給与（円） 6504047
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E02809
# 業種 卸売業
# 企業名 ナガイレーベン株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03270-000_2020-08-31_01_2020-11-20.xbrl : 58 / 330
# 当期純利益 6056000000
# 総資産 128190000000
# 自己資本利益率 0.118
# 従業員数（人） 2704
# 臨時雇用者数 2117
# 従業員数（人） 2704
# 臨時雇用者数 2117
# 従業員数（人） 2704
# 臨時雇用者数 2117
# 平均年齢（年） 39.7
# 平均勤続年数（年） 14.7
# 平均年間給与（円） 4662000
# 男性役員数（人） 8
# 女性役員数（人） 1
# EDINETコード E03270
# 業種 小売業
# 企業名 株式会社コジマ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03481-000_2020-08-31_01_2020-11-20.xbrl : 59 / 330
# 当期純利益 -424000000
# 総資産 332070000000
# 自己資本利益率
# 従業員数（人） 4556
# 臨時雇用者数 2032
# 従業員数（人） 4556
# 臨時雇用者数 2032
# 従業員数（人） 4556
# 臨時雇用者数 2032
# 平均年齢（年） 34.4
# 平均勤続年数（年） 10.8
# 平均年間給与（円） 4359534
# 男性役員数（人） 11
# 女性役員数（人） 2
# EDINETコード E03481
# 業種 小売業
# 企業名 株式会社ビックカメラ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02896-000_2020-08-31_01_2020-11-20.xbrl : 60 / 330
# 当期純利益 2675108000
# 総資産 41753630000
# 自己資本利益率 0.1070
# 従業員数（人） 507
# 臨時雇用者数 73
# 従業員数（人） 507
# 臨時雇用者数 73
# 平均年齢（年） 36.9
# 平均勤続年数（年） 10.2
# 平均年間給与（円） 5989716
# 男性役員数（人） 9
# 女性役員数（人） 0
# EDINETコード E02896
# 業種 卸売業
# 企業名 株式会社進和
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00246-000_2020-08-31_01_2020-11-20.xbrl : 61 / 330
# 当期純利益 655526000
# 総資産 8796854000
# 自己資本利益率 0.136
# 従業員数（人） 119
# 臨時雇用者数 20
# 従業員数（人） 119
# 平均年齢（年） 41.8
# 平均勤続年数（年） 17.0
# 平均年間給与（円） 5973000
# 臨時雇用者数 20
# 従業員数（人） 119
# 臨時雇用者数 20
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E00246
# 業種 建設業
# 企業名 暁飯島工業株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02478-000_2020-08-31_01_2020-11-20.xbrl : 62 / 330
# 当期純利益 384588000
# 総資産 12368216000
# 自己資本利益率 0.035
# 従業員数（人） 232
# 従業員数（人） 232
# 平均年齢（年） 41.9
# 平均勤続年数（年） 16.5
# 平均年間給与（円） 5354000
# 男性役員数（人） 10
# 女性役員数（人） 1
# EDINETコード E02478
# 業種 機械
# 企業名 ミクロン精密株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E33807-000_2020-08-31_01_2020-11-20.xbrl : 63 / 330
# 当期純利益 527810000
# 総資産 7964110000
# 自己資本利益率 0.0791
# 従業員数（人） 59
# 臨時雇用者数 13
# 従業員数（人） 59
# 平均年齢（年） 30.7
# 平均勤続年数（年） 2.8
# 平均年間給与（円） 4397000
# 臨時雇用者数 13
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E33807
# 業種 卸売業
# 企業名 バリュエンスホールディングス株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05622-000_2020-08-31_01_2020-11-20.xbrl : 64 / 330
# 当期純利益 -217126000
# 総資産 3209316000
# 自己資本利益率 -0.168
# 従業員数（人） 92
# 臨時雇用者数 5
# 従業員数（人） 92
# 臨時雇用者数 5
# 平均年齢（年） 34.0
# 平均勤続年数（年） 4.8
# 平均年間給与（円） 4357000
# 従業員数（人） 92
# 臨時雇用者数 5
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E05622
# 業種 情報・通信業
# 企業名 株式会社メディア工房
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04706-000_2020-08-31_01_2020-11-24.xbrl : 65 / 330
# 当期純利益 51058000
# 総資産 990427000
# 自己資本利益率 0.139
# 従業員数（人） 27
# 臨時雇用者数 14
# EDINETコード E04706
# 業種 サービス業
# 企業名 株式会社　高滝リンクス倶楽部
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00600-000_2020-08-31_01_2020-11-24.xbrl : 66 / 330
# 当期純利益 -1280811000
# 総資産 20637048000
# 自己資本利益率
# 従業員数（人） 185
# 臨時雇用者数 1089
# 従業員数（人） 185
# 臨時雇用者数 1089
# 平均年齢（年） 43.3
# 平均勤続年数（年） 19.4
# 平均年間給与（円） 5726889
# 従業員数（人） 185
# 臨時雇用者数 1089
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E00600
# 業種 繊維製品
# 企業名 ヤマトインターナショナル株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E32991-000_2020-08-31_01_2020-11-24.xbrl : 67 / 330
# 当期純利益 151915000
# 総資産 5200901000
# 自己資本利益率 0.041
# 従業員数（人） 105
# 臨時雇用者数 29
# 従業員数（人） 105
# 平均年齢（年） 39.6
# 平均勤続年数（年） 6
# 平均年間給与（円） 6471000
# 臨時雇用者数 29
# 男性役員数（人） 6
# 女性役員数（人） 2
# EDINETコード E32991
# 業種 小売業
# 企業名 株式会社ほぼ日
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04981-000_2020-08-31_01_2020-11-25.xbrl : 68 / 330
# 当期純利益 -1673000000
# 総資産 11871000000
# 自己資本利益率 -0.141
# 従業員数（人） 583
# 臨時雇用者数 1580
# 従業員数（人） 583
# 臨時雇用者数 1580
# 平均年齢（年） 36.7
# 平均勤続年数（年） 7.7
# 平均年間給与（円） 4918946
# 従業員数（人） 583
# 臨時雇用者数 1580
# 男性役員数（人） 6
# 女性役員数（人） 2
# EDINETコード E04981
# 業種 サービス業
# 企業名 株式会社明光ネットワークジャパン
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E01064-000_2020-08-31_01_2020-11-25.xbrl : 69 / 330
# 当期純利益 548850000
# 総資産 15305528000
# 自己資本利益率 0.060
# 従業員数（人） 346
# 臨時雇用者数 82
# 従業員数（人） 346
# 平均年齢（年） 38
# 平均勤続年数（年） 8
# 平均年間給与（円） 4011856
# 臨時雇用者数 82
# 従業員数（人） 346
# 臨時雇用者数 82
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E01064
# 業種 食料品
# 企業名 株式会社ＡＦＣ－ＨＤアムスライフサイエンス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03271-000_2020-08-31_01_2020-11-25.xbrl : 70 / 330
# 当期純利益 -884000000
# 総資産 38007000000
# 自己資本利益率 -0.062
# 従業員数（人） 691
# 臨時雇用者数 1539
# 従業員数（人） 691
# 臨時雇用者数 1539
# 平均年齢（年） 37.61
# 平均勤続年数（年） 11.95
# 平均年間給与（円） 4943000
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E03271
# 業種 小売業
# 企業名 株式会社ヒマラヤ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00327-000_2020-08-31_01_2020-11-25.xbrl : 71 / 330
# 当期純利益 1877000000
# 総資産 42794000000
# 自己資本利益率 0.168
# 従業員数（人） 70
# 臨時雇用者数
# 従業員数（人） 70
# 臨時雇用者数
# 平均年齢（年） 43.2
# 平均勤続年数（年） 8.3
# 平均年間給与（円） 6625898
# 従業員数（人） 70
# 臨時雇用者数
# 男性役員数（人） 10
# 女性役員数（人） 0
# EDINETコード E00327
# 業種 建設業
# 企業名 株式会社ウエストホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03391-000_2020-08-31_01_2020-11-25.xbrl : 72 / 330
# 当期純利益 132226000
# 総資産 17554663000
# 自己資本利益率 0.015
# 従業員数（人） 75
# 臨時雇用者数 14
# 従業員数（人） 75
# 臨時雇用者数 14
# 平均年齢（年） 44.6
# 平均勤続年数（年） 12.9
# 平均年間給与（円） 5018000
# 従業員数（人） 75
# 臨時雇用者数 14
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E03391
# 業種 小売業
# 企業名 株式会社ワッツ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E32380-000_2020-08-31_01_2020-11-25.xbrl : 73 / 330
# 当期純利益 2202581000
# 総資産 9045900000
# 自己資本利益率 0.360
# 従業員数（人） 140
# 臨時雇用者数 23
# 従業員数（人） 140
# 臨時雇用者数 23
# 平均年齢（年） 35.5
# 平均勤続年数（年） 2.6
# 平均年間給与（円） 13574000
# 従業員数（人） 140
# 臨時雇用者数 23
# 男性役員数（人） 7
# 女性役員数（人） 2
# EDINETコード E32380
# 業種 サービス業
# 企業名 株式会社ストライク
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E31968-000_2020-08-31_01_2020-11-26.xbrl : 74 / 330
# 当期純利益 44144000
# 総資産 1900436000
# 自己資本利益率 0.027
# 従業員数（人） 19
# 臨時雇用者数 3
# 従業員数（人） 19
# 臨時雇用者数 3
# 平均年齢（年） 44.7
# 平均勤続年数（年） 8.8
# 平均年間給与（円） 4200000
# 男性役員数（人） 6
# 女性役員数（人）
# EDINETコード E31968
# 業種 小売業
# 企業名 アクサスホールディングス株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E01690-000_2020-08-31_01_2020-11-26.xbrl : 75 / 330
# 当期純利益 837000000
# 総資産 44586000000
# 自己資本利益率 0.024
# 従業員数（人） 453
# 従業員数（人） 453
# 平均年齢（年） 33.8
# 平均勤続年数（年） 10.6
# 平均年間給与（円） 6315000
# 従業員数（人） 453
# 男性役員数（人） 11
# 女性役員数（人） 2
# EDINETコード E01690
# 業種 機械
# 企業名 株式会社技研製作所
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03221-000_2020-08-31_01_2020-11-26.xbrl : 76 / 330
# 当期純利益 287044000
# 総資産 1108228000
# 自己資本利益率 -0.1389
# 従業員数（人） 4
# 臨時雇用者数
# 従業員数（人） 4
# 臨時雇用者数
# 平均年齢（年） 53
# 平均勤続年数（年） 16
# 平均年間給与（円） 5324198
# 従業員数（人） 4
# 臨時雇用者数
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E03221
# 業種 小売業
# 企業名 株式会社文教堂グループホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02493-000_2020-08-31_01_2020-11-26.xbrl : 77 / 330
# 当期純利益 420745000
# 総資産 10411105000
# 自己資本利益率 0.048
# 従業員数（人） 108
# 臨時雇用者数 63
# 従業員数（人） 108
# 臨時雇用者数 63
# 平均年齢（年） 43.5
# 平均勤続年数（年） 8.4
# 平均年間給与（円） 4767000
# 従業員数（人） 108
# 臨時雇用者数 63
# 男性役員数（人） 10
# 女性役員数（人）
# EDINETコード E02493
# 業種 金属製品
# 企業名 日創プロニティ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34225-000_2020-08-31_01_2020-11-26.xbrl : 78 / 330
# 当期純利益 242792000
# 総資産 2774764000
# 自己資本利益率 0.190
# 従業員数（人） 95
# 臨時雇用者数 3
# 従業員数（人） 95
# 臨時雇用者数 3
# 平均年齢（年） 37.0
# 平均勤続年数（年） 2.8
# 平均年間給与（円） 7579000
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E34225
# 業種 情報・通信業
# 企業名 株式会社チームスピリット
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00617-000_2020-08-31_01_2020-11-26.xbrl : 79 / 330
# 当期純利益 -752237000
# 総資産 8826189000
# 自己資本利益率 -0.1486
# 従業員数（人） 25
# 臨時雇用者数
# 従業員数（人） 25
# 臨時雇用者数
# 平均年齢（年） 37.9
# 平均勤続年数（年） 7.8
# 平均年間給与（円） 5242270
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E00617
# 業種 繊維製品
# 企業名 株式会社クラウディアホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E31425-000_2020-08-31_01_2020-11-26.xbrl : 80 / 330
# 当期純利益 154469000
# 総資産 3404515000
# 自己資本利益率 0.050
# 従業員数（人） 75
# 臨時雇用者数 68
# 従業員数（人） 75
# 臨時雇用者数 68
# 平均年齢（年） 34.4
# 平均勤続年数（年） 3.8
# 平均年間給与（円） 5562000
# 従業員数（人） 75
# 臨時雇用者数 68
# 男性役員数（人） 7
# 女性役員数（人） 0
# EDINETコード E31425
# 業種 サービス業
# 企業名 株式会社デザインワン・ジャパン
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E25443-000_2020-08-31_01_2020-11-26.xbrl : 81 / 330
# 当期純利益 381122000
# 総資産 16518299000
# 自己資本利益率 0.051
# 従業員数（人） 121
# 従業員数（人） 121
# 平均年齢（年） 41.6
# 平均勤続年数（年） 13.7
# 平均年間給与（円） 4567000
# 従業員数（人） 121
# 男性役員数（人） 11
# 女性役員数（人） 1
# EDINETコード E25443
# 業種 卸売業
# 企業名 黒谷株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02340-000_2020-08-31_01_2020-11-26.xbrl : 82 / 330
# 当期純利益 3376567000
# 総資産 35285392000
# 自己資本利益率 0.103
# 従業員数（人） 320
# 臨時雇用者数 6
# 従業員数（人） 320
# 臨時雇用者数 6
# 平均年齢（年） 41.5
# 平均勤続年数（年） 15.2
# 平均年間給与（円） 6200407
# 従業員数（人） 320
# 臨時雇用者数 6
# 男性役員数（人） 8
# 女性役員数（人） 1
# EDINETコード E02340
# 業種 精密機器
# 企業名 マニー株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34729-000_2020-08-31_01_2020-11-26.xbrl : 83 / 330
# 当期純利益 577132000
# 総資産 7059882000
# 自己資本利益率 0.154
# 従業員数（人） 308
# 臨時雇用者数 93
# 従業員数（人） 308
# 臨時雇用者数 93
# 平均年齢（年） 32.0
# 平均勤続年数（年） 4.4
# 平均年間給与（円） 4029000
# 従業員数（人） 308
# 臨時雇用者数 93
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E34729
# 業種 情報・通信業
# 企業名 株式会社東名
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03305-000_2020-08-31_01_2020-11-26.xbrl : 84 / 330
# 当期純利益 -4090000000
# 総資産 90518000000
# 自己資本利益率
# 従業員数（人） 2082
# 臨時雇用者数 7941
# 従業員数（人） 2082
# 臨時雇用者数 7941
# 平均年齢（年） 38
# 平均勤続年数（年） 13
# 平均年間給与（円） 5893217
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E03305
# 業種 小売業
# 企業名 株式会社サイゼリヤ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E30999-000_2020-08-31_01_2020-11-26.xbrl : 85 / 330
# 当期純利益 40363000
# 総資産 1805877000
# 自己資本利益率 0.104
# 従業員数（人） 245
# 臨時雇用者数 73
# 従業員数（人） 245
# 臨時雇用者数 73
# 平均年齢（年） 33.8
# 平均勤続年数（年） 4.0
# 平均年間給与（円） 3825000
# 男性役員数（人） 7
# 女性役員数（人） 3
# EDINETコード E30999
# 業種 サービス業
# 企業名 日本ＰＣサービス株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E31741-000_2020-08-31_01_2020-11-26.xbrl : 86 / 330
# 当期純利益 71572000
# 総資産 7048306000
# 自己資本利益率 0.022
# 従業員数（人） 23
# 従業員数（人） 23
# 平均年齢（年） 44.6
# 平均勤続年数（年） 7.3
# 平均年間給与（円） 5718000
# 従業員数（人） 23
# 男性役員数（人） 8
# 女性役員数（人） 2
# EDINETコード E31741
# 業種 建設業
# 企業名 JESCOホールディングス株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05498-000_2020-08-31_01_2020-11-26.xbrl : 87 / 330
# 当期純利益 317794000
# 総資産 4742807000
# 自己資本利益率 0.079
# 従業員数（人） 214
# 臨時雇用者数 32
# 従業員数（人） 214
# 臨時雇用者数 32
# 平均年齢（年） 36.2
# 平均勤続年数（年） 6.5
# 平均年間給与（円） 5709046
# 男性役員数（人） 7
# 女性役員数（人） 1
# EDINETコード E05498
# 業種 サービス業
# 企業名 株式会社プラップジャパン
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E31743-000_2020-08-31_01_2020-11-26.xbrl : 88 / 330
# 当期純利益 982324000
# 総資産 19948547000
# 自己資本利益率 0.1567
# 従業員数（人） 184
# 従業員数（人） 184
# 平均年齢（年） 38.1
# 平均勤続年数（年） 8.1
# 平均年間給与（円） 7488193
# 従業員数（人） 184
# 男性役員数（人） 11
# 女性役員数（人） 1
# EDINETコード E31743
# 業種 サービス業
# 企業名 ユーピーアール株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E33237-000_2020-08-31_01_2020-11-26.xbrl : 89 / 330
# 当期純利益 -406323000
# 総資産 1824193000
# 自己資本利益率
# 従業員数（人） 120
# 臨時雇用者数 9
# 従業員数（人） 120
# 臨時雇用者数 9
# 平均年齢（年） 36.7
# 平均勤続年数（年） 3.6
# 平均年間給与（円） 4442000
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E33237
# 業種 サービス業
# 企業名 エコモット株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35488-000_2020-08-31_01_2020-11-26.xbrl : 90 / 330
# 当期純利益 3837801000
# 総資産 27056953000
# 自己資本利益率 0.648
# 従業員数（人） 27
# 従業員数（人） 27
# 平均年齢（年） 36.6
# 平均勤続年数（年） 3.9
# 平均年間給与（円） 5455000
# 男性役員数（人） 6
# 女性役員数（人） 1
# EDINETコード E35488
# 業種 サービス業
# 企業名 株式会社カーブスホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34238-000_2020-08-31_01_2020-11-26.xbrl : 91 / 330
# 当期純利益 -362077000
# 総資産 6343848000
# 自己資本利益率
# 従業員数（人） 119
# 臨時雇用者数 59
# 従業員数（人） 119
# 臨時雇用者数 59
# 平均年齢（年） 31.4
# 平均勤続年数（年） 1.8
# 平均年間給与（円） 5426000
# 従業員数（人） 119
# 臨時雇用者数 59
# 男性役員数（人） 8
# 女性役員数（人） 1
# EDINETコード E34238
# 業種 サービス業
# 企業名 ａｎｄ　ｆａｃｔｏｒｙ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35767-000_2020-08-31_01_2020-11-26.xbrl : 92 / 330
# 当期純利益 80331000
# 総資産 1137778000
# 自己資本利益率 0.205
# 従業員数（人） 165
# 臨時雇用者数 15
# 従業員数（人） 165
# 平均年齢（年） 30.3
# 平均勤続年数（年） 1.4
# 平均年間給与（円） 3886000
# 臨時雇用者数 15
# 従業員数（人） 165
# 臨時雇用者数 15
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E35767
# 業種 サービス業
# 企業名 株式会社Ｂｒａｎｄｉｎｇ Ｅｎｇｉｎｅｅｒ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E33364-000_2020-08-31_01_2020-11-26.xbrl : 93 / 330
# 当期純利益 226106000
# 総資産 1942328000
# 自己資本利益率 0.246
# 従業員数（人） 120
# 臨時雇用者数 21
# 従業員数（人） 120
# 臨時雇用者数 21
# 平均年齢（年） 28.3
# 平均勤続年数（年） 2.0
# 平均年間給与（円） 5781000
# 男性役員数（人） 3
# 女性役員数（人） 2
# EDINETコード E33364
# 業種 情報・通信業
# 企業名 ウォンテッドリー株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00311-000_2020-08-31_01_2020-11-26.xbrl : 94 / 330
# 当期純利益 799913000
# 総資産 37319510000
# 自己資本利益率 0.036
# 従業員数（人） 346
# 臨時雇用者数 22
# 従業員数（人） 346
# 臨時雇用者数 22
# 平均年齢（年） 32.9
# 平均勤続年数（年） 7.6
# 平均年間給与（円） 5409000
# 従業員数（人） 346
# 臨時雇用者数 22
# 男性役員数（人） 12
# 女性役員数（人）
# EDINETコード E00311
# 業種 不動産業
# 企業名 株式会社ＡＶＡＮＴＩＡ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03000-000_2020-08-31_01_2020-11-26.xbrl : 95 / 330
# 当期純利益 188716000
# 総資産 6186257000
# 自己資本利益率 0.046
# 従業員数（人） 35
# 臨時雇用者数 6
# 従業員数（人） 35
# 臨時雇用者数 6
# 平均年齢（年） 51.38
# 平均勤続年数（年） 11.68
# 平均年間給与（円） 3429913
# 従業員数（人） 35
# 臨時雇用者数 6
# 男性役員数（人） 6
# 女性役員数（人）
# EDINETコード E03000
# 業種 卸売業
# 企業名 株式会社カワサキ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34739-000_2020-08-31_01_2020-11-26.xbrl : 96 / 330
# 当期純利益 202966000
# 総資産 2339675000
# 自己資本利益率 0.1181
# 従業員数（人） 157
# 従業員数（人） 157
# 平均年齢（年） 35.01
# 平均勤続年数（年） 7.02
# 平均年間給与（円） 5419947
# 従業員数（人） 157
# 男性役員数（人） 13
# 女性役員数（人）
# EDINETコード E34739
# 業種 情報・通信業
# 企業名 株式会社ヴィッツ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03471-000_2020-08-31_01_2020-11-26.xbrl : 97 / 330
# 当期純利益 -1844000000
# 総資産 36784000000
# 自己資本利益率 -0.104
# 従業員数（人） 53
# 臨時雇用者数 5
# 従業員数（人） 53
# 臨時雇用者数 5
# 平均年齢（年） 38.8
# 平均勤続年数（年） 6.3
# 平均年間給与（円） 6626197
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E03471
# 業種 小売業
# 企業名 株式会社ジンズホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04656-000_2020-08-31_01_2020-11-27.xbrl : 98 / 330
# 当期純利益 9352000
# 総資産 899464000
# 自己資本利益率 0.059
# 従業員数（人） 27
# 臨時雇用者数 17
# EDINETコード E04656
# 業種 サービス業
# 企業名 鳴門ゴルフ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03217-000_2020-08-31_01_2020-11-27.xbrl : 99 / 330
# 当期純利益 62422000000
# 総資産 1063356000000
# 自己資本利益率 0.119
# 従業員数（人） 1589
# 臨時雇用者数 8
# 従業員数（人） 1589
# 臨時雇用者数 8
# 平均年齢（年） 37
# 平均勤続年数（年） 4
# 平均年間給与（円） 9013000
# 男性役員数（人） 13
# 女性役員数（人） 2
# EDINETコード E03217
# 業種 小売業
# 企業名 株式会社ファーストリテイリング
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03074-000_2020-08-31_01_2020-11-27.xbrl : 100 / 330
# 当期純利益 6422000000
# 総資産 237346000000
# 自己資本利益率 0.035
# 従業員数（人） 1579
# 臨時雇用者数 2940
# 従業員数（人） 1579
# 臨時雇用者数 2940
# 平均年齢（年） 37.1
# 平均勤続年数（年） 10.1
# 平均年間給与（円） 4929000
# 従業員数（人） 1579
# 臨時雇用者数 2940
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E03074
# 業種 小売業
# 企業名 株式会社島忠
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05083-000_2020-08-31_01_2020-11-27.xbrl : 101 / 330
# 当期純利益 -645446000
# 総資産 3881372000
# 自己資本利益率
# 従業員数（人） 358
# 臨時雇用者数 27
# 従業員数（人） 358
# 臨時雇用者数 27
# 平均年齢（年） 37.9
# 平均勤続年数（年） 12.7
# 平均年間給与（円） 4813112
# 男性役員数（人） 10
# 女性役員数（人）
# EDINETコード E05083
# 業種 サービス業
# 企業名 株式会社アルファ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34289-000_2020-08-31_01_2020-11-27.xbrl : 102 / 330
# 当期純利益 197308000
# 総資産 8486104000
# 自己資本利益率 0.072
# 従業員数（人） 90
# 臨時雇用者数
# 従業員数（人） 90
# 平均年齢（年） 37.1
# 平均勤続年数（年） 1.2
# 平均年間給与（円） 9983000
# 従業員数（人） 90
# 男性役員数（人） 11
# 女性役員数（人）
# EDINETコード E34289
# 業種 不動産業
# 企業名 霞ヶ関キャピタル株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E01031-000_2020-08-31_01_2020-11-27.xbrl : 103 / 330
# 当期純利益 53118000
# 総資産 3326961000
# 自己資本利益率 0.0189
# 従業員数（人） 170
# 臨時雇用者数 18
# 従業員数（人） 170
# 臨時雇用者数 18
# 平均年齢（年） 38.2
# 平均勤続年数（年） 9.4
# 平均年間給与（円） 3934106
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E01031
# 業種 化学
# 企業名 旭化学工業株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05042-000_2020-08-31_01_2020-11-27.xbrl : 104 / 330
# 当期純利益 178355000
# 総資産 6833117000
# 自己資本利益率 0.031
# 従業員数（人） 524
# 臨時雇用者数 10
# 従業員数（人） 524
# 臨時雇用者数 10
# 平均年齢（年） 32.3
# 平均勤続年数（年） 8.1
# 平均年間給与（円） 4003000
# 従業員数（人） 524
# 臨時雇用者数 10
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E05042
# 業種 情報・通信業
# 企業名 株式会社トーセ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03459-000_2020-08-31_01_2020-11-27.xbrl : 105 / 330
# 当期純利益 102707000
# 総資産 8518647000
# 自己資本利益率 0.018
# 従業員数（人） 219
# 臨時雇用者数 29
# 従業員数（人） 219
# 臨時雇用者数 29
# 平均年齢（年） 34.0
# 平均勤続年数（年） 6.3
# 平均年間給与（円） 3859807
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E03459
# 業種 小売業
# 企業名 株式会社オンリー
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E32397-000_2020-08-31_01_2020-11-27.xbrl : 106 / 330
# 当期純利益 706320000
# 総資産 7399513000
# 自己資本利益率 0.219
# 従業員数（人） 2505
# 従業員数（人） 2505
# 平均年齢（年） 29.9
# 平均勤続年数（年） 3.1
# 平均年間給与（円） 3654000
# 従業員数（人） 2505
# 男性役員数（人） 8
# 女性役員数（人） 0
# EDINETコード E32397
# 業種 サービス業
# 企業名 株式会社セラク
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02238-000_2020-08-31_01_2020-11-27.xbrl : 107 / 330
# 当期純利益 175817000
# 総資産 10832714000
# 自己資本利益率 0.0219
# 従業員数（人） 253
# 臨時雇用者数 42
# 従業員数（人） 253
# 臨時雇用者数 42
# 平均年齢（年） 40.9
# 平均勤続年数（年） 16.9
# 平均年間給与（円） 5397000
# 従業員数（人） 253
# 臨時雇用者数 42
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E02238
# 業種 輸送用機器
# 企業名 株式会社エッチ・ケー・エス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02092-000_2020-08-31_01_2020-11-27.xbrl : 108 / 330
# 当期純利益 506781000
# 総資産 7972706000
# 自己資本利益率 0.109
# 従業員数（人） 158
# 臨時雇用者数 41
# 従業員数（人） 158
# 臨時雇用者数 41
# 平均年齢（年） 39.8
# 平均勤続年数（年） 8.9
# 平均年間給与（円） 5056788
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E02092
# 業種 電気機器
# 企業名 株式会社アドテック　プラズマ　テクノロジー
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03392-000_2020-08-31_01_2020-11-27.xbrl : 109 / 330
# 当期純利益 -71514000
# 総資産 1678347000
# 自己資本利益率 -0.049
# 従業員数（人）
# 臨時雇用者数
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E03392
# 業種 小売業
# 企業名 フェスタリアホールディングス株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05716-000_2020-08-31_01_2020-11-27.xbrl : 110 / 330
# 当期純利益 -348106000
# 総資産 1264626000
# 自己資本利益率 -1.194
# 従業員数（人） 169
# 臨時雇用者数 78
# 従業員数（人） 169
# 臨時雇用者数 78
# 平均年齢（年） 35.9
# 平均勤続年数（年） 6.6
# 平均年間給与（円） 4523000
# 男性役員数（人） 6
# 女性役員数（人） 1
# EDINETコード E05716
# 業種 サービス業
# 企業名 株式会社地域新聞社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E33514-000_2020-08-31_01_2020-11-27.xbrl : 111 / 330
# 当期純利益 181147000
# 総資産 4926912000
# 自己資本利益率 0.097
# 従業員数（人） 72
# 従業員数（人） 72
# 平均年齢（年） 38.2
# 平均勤続年数（年） 9.6
# 平均年間給与（円） 4670954
# 従業員数（人） 72
# 男性役員数（人） 13
# 女性役員数（人）
# EDINETコード E33514
# 業種 卸売業
# 企業名 ポエック株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E32351-000_2020-08-31_01_2020-11-27.xbrl : 112 / 330
# 当期純利益 31289000
# 総資産 1751262000
# 自己資本利益率 0.0499
# 従業員数（人） 117
# 臨時雇用者数 89
# 従業員数（人） 117
# 臨時雇用者数 89
# 平均年齢（年） 33.6
# 平均勤続年数（年） 3.2
# 平均年間給与（円） 3884000
# 従業員数（人） 117
# 臨時雇用者数 89
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E32351
# 業種 サービス業
# 企業名 株式会社農業総合研究所
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04059-000_2020-08-31_01_2020-11-27.xbrl : 113 / 330
# 当期純利益 3263809000
# 総資産 94487625000
# 自己資本利益率 0.086
# 従業員数（人） 563
# 臨時雇用者数 34
# 従業員数（人） 563
# 臨時雇用者数 34
# 平均年齢（年） 33.5
# 平均勤続年数（年） 5.0
# 平均年間給与（円） 5659348
# 従業員数（人） 563
# 臨時雇用者数 34
# 男性役員数（人） 10
# 女性役員数（人） 1
# EDINETコード E04059
# 業種 不動産業
# 企業名 株式会社三栄建築設計
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E26579-000_2020-08-31_01_2020-11-27.xbrl : 114 / 330
# 当期純利益 -189108000
# 総資産 10419666000
# 自己資本利益率 -0.079
# 従業員数（人） 319
# 臨時雇用者数 161
# 従業員数（人） 319
# 臨時雇用者数 161
# 平均年齢（年） 39.1
# 平均勤続年数（年） 6.27
# 平均年間給与（円） 3725000
# 従業員数（人） 319
# 臨時雇用者数 161
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E26579
# 業種 小売業
# 企業名 株式会社ハピネス・アンド・ディ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04751-000_2020-08-31_01_2020-11-27.xbrl : 115 / 330
# 当期純利益 891448000
# 総資産 29041217000
# 自己資本利益率 0.055
# 従業員数（人） 14
# 臨時雇用者数
# 従業員数（人） 14
# 臨時雇用者数
# 平均年齢（年） 48.7
# 平均勤続年数（年） 5.9
# 平均年間給与（円） 7019000
# 従業員数（人） 14
# 臨時雇用者数
# 男性役員数（人） 7
# 女性役員数（人） 1
# EDINETコード E04751
# 業種 サービス業
# 企業名 株式会社コシダカホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E24753-000_2020-08-31_01_2020-11-27.xbrl : 116 / 330
# 当期純利益 625416000
# 総資産 5619320000
# 自己資本利益率 0.145
# 従業員数（人） 29
# 臨時雇用者数 0
# 従業員数（人） 29
# 臨時雇用者数 0
# 平均年齢（年） 40.5
# 平均勤続年数（年） 6.1
# 平均年間給与（円） 5400000
# 男性役員数（人） 6
# 女性役員数（人） 2
# EDINETコード E24753
# 業種 その他製品
# 企業名 株式会社トランザクション
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05409-000_2020-08-31_01_2020-11-27.xbrl : 117 / 330
# 当期純利益 -1582575000
# 総資産 5468097000
# 自己資本利益率 -3.125
# 従業員数（人） 175
# 臨時雇用者数 395
# 従業員数（人） 175
# 臨時雇用者数 395
# 平均年齢（年） 35.0
# 平均勤続年数（年） 5.1
# 平均年間給与（円） 4304612
# 従業員数（人） 175
# 臨時雇用者数 395
# 男性役員数（人） 6
# 女性役員数（人）
# EDINETコード E05409
# 業種 サービス業
# 企業名 株式会社鉄人化計画
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E30969-000_2020-08-31_01_2020-11-27.xbrl : 118 / 330
# 当期純利益 1191126000
# 総資産 17274550000
# 自己資本利益率 0.131
# 従業員数（人） 1581
# 臨時雇用者数 877
# 従業員数（人） 1581
# 臨時雇用者数 877
# 平均年齢（年） 35
# 平均勤続年数（年） 2
# 平均年間給与（円） 5680020
# 従業員数（人） 1581
# 臨時雇用者数 877
# 男性役員数（人） 7
# 女性役員数（人） 1
# EDINETコード E30969
# 業種 情報・通信業
# 企業名 株式会社ＳＨＩＦＴ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05584-000_2020-08-31_01_2020-11-27.xbrl : 119 / 330
# 当期純利益 -4217684000
# 総資産 35918499000
# 自己資本利益率 -0.267
# 従業員数（人） 267
# 臨時雇用者数 2510
# 従業員数（人） 267
# 臨時雇用者数 2510
# 平均年齢（年） 34.5
# 平均勤続年数（年） 2.2
# 平均年間給与（円） 5610000
# 従業員数（人） 267
# 臨時雇用者数 2510
# 男性役員数（人） 10
# 女性役員数（人） 1
# EDINETコード E05584
# 業種 情報・通信業
# 企業名 株式会社出前館
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03240-000_2020-08-31_01_2020-11-27.xbrl : 120 / 330
# 当期純利益 -5842000000
# 総資産 39561000000
# 自己資本利益率 -0.2973
# 従業員数（人） 917
# 臨時雇用者数 2092
# 従業員数（人） 917
# 臨時雇用者数 2092
# 平均年齢（年） 33.3
# 平均勤続年数（年） 10.6
# 平均年間給与（円） 4095000
# 男性役員数（人） 8
# 女性役員数（人） 1
# EDINETコード E03240
# 業種 小売業
# 企業名 株式会社ライトオン
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03248-000_2020-08-31_01_2020-11-30.xbrl : 121 / 330
# 当期純利益 -17670000000
# 総資産 251141000000
# 自己資本利益率
# 従業員数（人） 2446
# 臨時雇用者数 6736
# 従業員数（人） 2446
# 臨時雇用者数 6736
# 平均年齢（年） 37.15
# 平均勤続年数（年） 7.32
# 平均年間給与（円） 5564343
# 従業員数（人） 2446
# 臨時雇用者数 6736
# 男性役員数（人） 12
# 女性役員数（人） 1
# EDINETコード E03248
# 業種 小売業
# 企業名 株式会社良品計画
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E01734-000_2020-08-31_01_2020-11-30.xbrl : 122 / 330
# 当期純利益 684675000
# 総資産 9874909000
# 自己資本利益率 0.105
# 従業員数（人） 152
# 臨時雇用者数 31
# 従業員数（人） 152
# 臨時雇用者数 31
# 平均年齢（年） 40.0
# 平均勤続年数（年） 9.7
# 平均年間給与（円） 4555908
# 従業員数（人） 152
# 臨時雇用者数 31
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E01734
# 業種 機械
# 企業名 株式会社エヌ・ピー・シー
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E30020-000_2020-08-31_01_2020-11-30.xbrl : 123 / 330
# 当期純利益 -376510000
# 総資産 2746829000
# 自己資本利益率
# 従業員数（人） 208
# 臨時雇用者数 123
# 従業員数（人） 208
# 臨時雇用者数 123
# 平均年齢（年） 32.6
# 平均勤続年数（年） 6.6
# 平均年間給与（円） 3388189
# 従業員数（人） 208
# 臨時雇用者数 123
# 男性役員数（人） 6
# 女性役員数（人） 2
# EDINETコード E30020
# 業種 小売業
# 企業名 株式会社ＡＮＡＰ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04677-000_2020-08-31_01_2020-11-30.xbrl : 124 / 330
# 当期純利益 -9572000
# 総資産 2251216000
# 自己資本利益率 -0.0045
# 従業員数（人） 21
# 臨時雇用者数 3
# EDINETコード E04677
# 業種 サービス業
# 企業名 御調観光開発株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E01465-000_2020-08-31_01_2020-11-30.xbrl : 125 / 330
# 当期純利益 690561000
# 総資産 8894466000
# 自己資本利益率 0.125
# 従業員数（人） 142
# 臨時雇用者数 102
# 従業員数（人） 142
# 臨時雇用者数 102
# 平均年齢（年） 37.7
# 平均勤続年数（年） 7.4
# 平均年間給与（円） 5069000
# EDINETコード E01465
# 業種 機械
# 企業名 株式会社マルマエ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E31052-000_2020-08-31_01_2020-11-30.xbrl : 126 / 330
# 当期純利益 2745000000
# 総資産 105649000000
# 自己資本利益率 0.214
# 従業員数（人） 213
# 臨時雇用者数 14
# 従業員数（人） 213
# 臨時雇用者数 14
# 平均年齢（年） 37.9
# 平均勤続年数（年） 8.7
# 平均年間給与（円） 5988000
# 従業員数（人） 213
# 臨時雇用者数 14
# 男性役員数（人） 14
# 女性役員数（人） 1
# EDINETコード E31052
# 業種 情報・通信業
# 企業名 株式会社ＵＳＥＮ－ＮＥＸＴ　ＨＯＬＤＩＮＧＳ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E24998-000_2020-08-31_01_2020-11-30.xbrl : 127 / 330
# 当期純利益 -24899000
# 総資産 3666538000
# 自己資本利益率 -0.011
# 従業員数（人） 14
# 臨時雇用者数
# 従業員数（人） 14
# 臨時雇用者数
# 平均年齢（年） 43.4
# 平均勤続年数（年） 1.9
# 平均年間給与（円） 5937000
# 従業員数（人） 14
# 臨時雇用者数
# 男性役員数（人） 7
# 女性役員数（人） 0
# EDINETコード E24998
# 業種 情報・通信業
# 企業名 株式会社ジー・スリーホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04608-000_2020-08-31_01_2020-11-30.xbrl : 128 / 330
# 当期純利益 -442216000
# 総資産 16579196000
# 自己資本利益率
# 従業員数（人） 104
# 臨時雇用者数 94
# EDINETコード E04608
# 業種 サービス業
# 企業名 株式会社明治座
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E36070-000_2020-08-31_01_2020-11-30.xbrl : 129 / 330
# 当期純利益 143962000
# 総資産 1054892000
# 自己資本利益率 0.413
# 従業員数（人） 84
# 臨時雇用者数 11
# 従業員数（人） 84
# 臨時雇用者数 11
# 平均年齢（年） 33.3
# 平均勤続年数（年） 3.8
# 平均年間給与（円） 5593000
# 従業員数（人） 84
# 臨時雇用者数 11
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E36070
# 業種 情報・通信業
# 企業名 アララ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34538-000_2020-08-31_01_2020-11-30.xbrl : 130 / 330
# 当期純利益 317000000
# 総資産 11389000000
# 自己資本利益率 0.029
# 従業員数（人） 16
# 臨時雇用者数
# 従業員数（人） 16
# 平均年齢（年） 44.4
# 平均勤続年数（年） 5.8
# 平均年間給与（円） 7010589
# 従業員数（人） 16
# 男性役員数（人） 7
# 女性役員数（人） 1
# EDINETコード E34538
# 業種 情報・通信業
# 企業名 株式会社ヒト・コミュニケーションズ・ホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35773-000_2020-08-31_01_2020-11-30.xbrl : 131 / 330
# 当期純利益 216741000
# 総資産 1387674000
# 自己資本利益率 0.301
# 従業員数（人） 143
# 臨時雇用者数 26
# 従業員数（人） 143
# 平均年齢（年） 32.8
# 平均勤続年数（年） 1.7
# 平均年間給与（円） 6197000
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E35773
# 業種 情報・通信業
# 企業名 株式会社グッドパッチ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05630-000_2020-08-31_01_2020-11-30.xbrl : 132 / 330
# 当期純利益 -867966000
# 総資産 1534987000
# 自己資本利益率 -0.621
# 従業員数（人） 37
# 臨時雇用者数 2
# 従業員数（人） 37
# 臨時雇用者数 2
# 平均年齢（年） 43.8
# 平均勤続年数（年） 7.9
# 平均年間給与（円） 4953000
# 従業員数（人） 37
# 臨時雇用者数 2
# 男性役員数（人） 11
# 女性役員数（人）
# EDINETコード E05630
# 業種 情報・通信業
# 企業名 株式会社アクロディア
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04675-000_2020-08-31_01_2020-11-30.xbrl : 133 / 330
# 当期純利益 -82219000
# 総資産 2702145000
# 自己資本利益率 -0.047
# 従業員数（人） 53
# 臨時雇用者数
# EDINETコード E04675
# 業種 サービス業
# 企業名 菊陽緑化興産株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03223-000_2020-08-31_01_2020-11-30.xbrl : 134 / 330
# 当期純利益 -6129000000
# 総資産 37430000000
# 自己資本利益率 -0.345
# 従業員数（人） 1968
# 臨時雇用者数 1744
# 従業員数（人） 1968
# 臨時雇用者数 1744
# 平均年齢（年） 44.7
# 平均勤続年数（年） 11.5
# 平均年間給与（円） 4242000
# 従業員数（人） 1968
# 臨時雇用者数 1744
# 男性役員数（人） 13
# 女性役員数（人）
# EDINETコード E03223
# 業種 小売業
# 企業名 株式会社大庄
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35280-000_2019-12-31_01_2020-11-30.xbrl : 135 / 330
# 当期純利益 -5081813000
# 総資産 16642029000
# 従業員数（人） 178
# EDINETコード E35280
# 業種 その他製品
# 企業名 Ｓｐｉｂｅｒ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E24991-000_2020-09-30_01_2020-12-04.xbrl : 136 / 330
# 当期純利益 6222000000
# 総資産 58724000000
# 自己資本利益率 0.107
# 従業員数（人） 100
# 臨時雇用者数 7
# 従業員数（人） 100
# 臨時雇用者数 7
# 平均年齢（年） 45.2
# 平均勤続年数（年） 6.7
# 平均年間給与（円） 5547176
# 男性役員数（人） 8
# 女性役員数（人） 3
# EDINETコード E24991
# 業種 化学
# 企業名 株式会社ノエビアホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00422-000_2020-09-20_01_2020-12-11.xbrl : 137 / 330
# 当期純利益 393469000
# 総資産 19832333000
# 自己資本利益率 0.075
# 従業員数（人） 330
# 臨時雇用者数 120
# 従業員数（人） 330
# 臨時雇用者数 120
# 平均年齢（年） 40.7
# 平均勤続年数（年） 17.4
# 平均年間給与（円） 6118980
# 従業員数（人） 330
# 臨時雇用者数 120
# 男性役員数（人） 11
# 女性役員数（人）
# EDINETコード E00422
# 業種 食料品
# 企業名 マルサンアイ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04925-000_2020-09-30_01_2020-12-14.xbrl : 138 / 330
# 当期純利益 1343218000
# 総資産 26036794000
# 自己資本利益率 0.065
# 従業員数（人） 820
# 臨時雇用者数 222
# 従業員数（人） 820
# 臨時雇用者数 222
# 従業員数（人） 820
# 臨時雇用者数 222
# 平均年齢（年） 37.5
# 平均勤続年数（年） 10.4
# 平均年間給与（円） 5842737
# 男性役員数（人） 12
# 女性役員数（人） 1
# EDINETコード E04925
# 業種 サービス業
# 企業名 株式会社ステップ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E31776-000_2020-09-30_01_2020-12-15.xbrl : 139 / 330
# 当期純利益 -291613000
# 総資産 3694462000
# 自己資本利益率 -0.107
# 従業員数（人） 11
# 臨時雇用者数
# 従業員数（人） 11
# 平均年齢（年） 33.60
# 平均勤続年数（年） 9.79
# 平均年間給与（円） 4600000
# 男性役員数（人） 11
# 女性役員数（人）
# EDINETコード E31776
# 業種 サービス業
# 企業名 株式会社ブランジスタ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34557-000_2020-09-30_01_2020-12-15.xbrl : 140 / 330
# 当期純利益 369670000
# 総資産 6173446000
# 自己資本利益率 0.2508
# 従業員数（人） 92
# 臨時雇用者数 2
# 従業員数（人） 92
# 臨時雇用者数 2
# 平均年齢（年） 31.4
# 平均勤続年数（年） 1.9
# 平均年間給与（円） 6302000
# 男性役員数（人） 8
# 女性役員数（人） 2
# EDINETコード E34557
# 業種 情報・通信業
# 企業名 株式会社マクアケ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05072-000_2020-09-30_01_2020-12-15.xbrl : 141 / 330
# 当期純利益 17723000000
# 総資産 189322000000
# 自己資本利益率 0.181
# 従業員数（人） 1587
# 臨時雇用者数 324
# 従業員数（人） 1587
# 臨時雇用者数 324
# 平均年齢（年） 33.2
# 平均勤続年数（年） 6.0
# 平均年間給与（円） 7336000
# 従業員数（人） 1587
# 臨時雇用者数 324
# 男性役員数（人） 7
# 女性役員数（人） 1
# EDINETコード E05072
# 業種 サービス業
# 企業名 株式会社サイバーエージェント
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02492-000_2020-09-20_01_2020-12-15.xbrl : 142 / 330
# 当期純利益 2105000000
# 総資産 46086000000
# 自己資本利益率 0.087
# 従業員数（人） 403
# 臨時雇用者数 90
# 従業員数（人） 403
# 臨時雇用者数 90
# 平均年齢（年） 40.4
# 平均勤続年数（年） 12.5
# 平均年間給与（円） 5624947
# 従業員数（人） 403
# 臨時雇用者数 90
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E02492
# 業種 その他製品
# 企業名 前田工繊株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04648-000_2020-09-30_01_2020-12-16.xbrl : 143 / 330
# 当期純利益 -62805000
# 総資産 3775966000
# 自己資本利益率 -0.088
# 従業員数（人） 46
# 臨時雇用者数 57
# EDINETコード E04648
# 業種 サービス業
# 企業名 呉羽観光株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05268-000_2020-09-30_01_2020-12-16.xbrl : 144 / 330
# 当期純利益 1673000000
# 総資産 13352000000
# 自己資本利益率 0.389
# 従業員数（人） 37
# 臨時雇用者数 21
# 従業員数（人） 37
# 臨時雇用者数 21
# 平均年齢（年） 34.68
# 平均勤続年数（年） 8.04
# 平均年間給与（円） 5000000
# 従業員数（人） 37
# 臨時雇用者数 21
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E05268
# 業種 サービス業
# 企業名 株式会社ネクシィーズグループ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05292-000_2020-09-30_01_2020-12-16.xbrl : 145 / 330
# 当期純利益 951000000
# 総資産 45044000000
# 自己資本利益率 0.067
# 従業員数（人） 206
# 臨時雇用者数 50
# 従業員数（人） 206
# 臨時雇用者数 50
# 平均年齢（年） 43.2
# 平均勤続年数（年） 6.5
# 平均年間給与（円） 8224607
# 男性役員数（人） 13
# 女性役員数（人） 2
# EDINETコード E05292
# 業種 サービス業
# 企業名 シミックホールディングス株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E21391-000_2020-09-30_01_2020-12-16.xbrl : 146 / 330
# 当期純利益 812000000
# 総資産 30820000000
# 自己資本利益率 0.068
# 従業員数（人） 44
# 臨時雇用者数
# 従業員数（人） 44
# 平均年齢（年） 41.6
# 平均勤続年数（年） 4.8
# 平均年間給与（円） 6006533
# 従業員数（人） 44
# 男性役員数（人） 10
# 女性役員数（人）
# EDINETコード E21391
# 業種 不動産業
# 企業名 株式会社アスコット
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35089-000_2020-09-30_01_2020-12-17.xbrl : 147 / 330
# 当期純利益 360114000
# 総資産 2375810000
# 自己資本利益率 0.2033
# 従業員数（人） 126
# 臨時雇用者数 13
# 従業員数（人） 126
# 臨時雇用者数 13
# 平均年齢（年） 28.7
# 平均勤続年数（年） 2.5
# 平均年間給与（円） 5261000
# 男性役員数（人） 6
# 女性役員数（人） 2
# EDINETコード E35089
# 業種 サービス業
# 企業名 株式会社サイバー・バズ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E01682-000_2020-09-30_01_2020-12-17.xbrl : 148 / 330
# 当期純利益 1979000000
# 総資産 43656000000
# 自己資本利益率 0.085
# 従業員数（人） 215
# 臨時雇用者数 42
# 従業員数（人） 215
# 臨時雇用者数 42
# 平均年齢（年） 41.7
# 平均勤続年数（年） 13.9
# 平均年間給与（円） 6910000
# 男性役員数（人） 11
# 女性役員数（人）
# EDINETコード E01682
# 業種 機械
# 企業名 日精エー・エス・ビー機械株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E30650-000_2020-09-30_01_2020-12-17.xbrl : 149 / 330
# 当期純利益 578565000
# 総資産 6006116000
# 自己資本利益率 0.144
# 従業員数（人） 116
# 臨時雇用者数 5
# 従業員数（人） 116
# 臨時雇用者数 5
# 平均年齢（年） 33.1
# 平均勤続年数（年） 2.1
# 平均年間給与（円） 6175000
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E30650
# 業種 サービス業
# 企業名 メドピア株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E31754-000_2020-09-30_01_2020-12-17.xbrl : 150 / 330
# 当期純利益 -146306000
# 総資産 3020212000
# 自己資本利益率
# 従業員数（人） 75
# 臨時雇用者数
# 従業員数（人） 75
# 平均年齢（年） 35.8
# 平均勤続年数（年） 4.7
# 平均年間給与（円） 5822000
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E31754
# 業種 情報・通信業
# 企業名 アイビーシー株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02865-000_2019-09-30_01_2019-12-20.xbrl : 151 / 330
# 当期純利益 765900000
# 総資産 10363725000
# 自己資本利益率 0.077
# 従業員数（人） 12
# 臨時雇用者数 3
# 従業員数（人） 12
# 臨時雇用者数 3
# 平均年齢（年） 47.9
# 平均勤続年数（年） 21.6
# 平均年間給与（円） 8471477
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E02865
# 業種 卸売業
# 企業名 株式会社アイナボホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05351-000_2020-09-30_01_2020-12-17.xbrl : 152 / 330
# 当期純利益 -842013000
# 総資産 5249563000
# 自己資本利益率 -0.230
# 従業員数（人） 78
# 臨時雇用者数 17
# 従業員数（人） 78
# 臨時雇用者数 17
# 平均年齢（年） 38.6
# 平均勤続年数（年） 9.3
# 平均年間給与（円） 5478541
# 従業員数（人） 78
# 臨時雇用者数 17
# 男性役員数（人） 10
# 女性役員数（人）
# EDINETコード E05351
# 業種 サービス業
# 企業名 株式会社メディネット
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E30537-000_2020-09-30_01_2020-12-17.xbrl : 153 / 330
# 当期純利益 532475000
# 総資産 7532962000
# 自己資本利益率 0.178
# 従業員数（人） 207
# 臨時雇用者数
# 従業員数（人） 207
# 平均年齢（年） 35.0
# 平均勤続年数（年） 4.7
# 平均年間給与（円） 7067000
# 従業員数（人） 207
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E30537
# 業種 情報・通信業
# 企業名 株式会社フィックスターズ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05414-000_2020-09-30_01_2020-12-18.xbrl : 154 / 330
# 当期純利益 748000000
# 総資産 35608000000
# 自己資本利益率 0.049
# 従業員数（人） 85
# 臨時雇用者数 3
# 従業員数（人） 85
# 臨時雇用者数 3
# 平均年齢（年） 32.1
# 平均勤続年数（年） 6.4
# 平均年間給与（円） 5610000
# 男性役員数（人） 8
# 女性役員数（人） 0
# EDINETコード E05414
# 業種 不動産業
# 企業名 パラカ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E01676-000_2020-09-30_01_2020-12-18.xbrl : 155 / 330
# 当期純利益 1360000000
# 総資産 35475000000
# 自己資本利益率 0.053
# 従業員数（人） 366
# 臨時雇用者数 71
# 従業員数（人） 366
# 臨時雇用者数 71
# 平均年齢（年） 42.3
# 平均勤続年数（年） 19.0
# 平均年間給与（円） 6944719
# 従業員数（人） 366
# 臨時雇用者数 71
# 男性役員数（人） 10
# 女性役員数（人） 0
# EDINETコード E01676
# 業種 機械
# 企業名 ホソカワミクロン株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02810-000_2020-09-30_01_2020-12-18.xbrl : 156 / 330
# 当期純利益 355571000
# 総資産 11662206000
# 自己資本利益率 0.066
# 従業員数（人） 228
# 従業員数（人） 228
# 平均年齢（年） 44.8
# 平均勤続年数（年） 17.3
# 平均年間給与（円） 4595000
# 従業員数（人） 228
# 男性役員数（人） 12
# 女性役員数（人）
# EDINETコード E02810
# 業種 卸売業
# 企業名 東北化学薬品株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02865-000_2020-09-30_01_2020-12-18.xbrl : 157 / 330
# 当期純利益 834788000
# 総資産 10768805000
# 自己資本利益率 0.080
# 従業員数（人） 16
# 臨時雇用者数 3
# 従業員数（人） 16
# 臨時雇用者数 3
# 平均年齢（年） 49.8
# 平均勤続年数（年） 20.8
# 平均年間給与（円） 8866380
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E02865
# 業種 卸売業
# 企業名 株式会社アイナボホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05360-000_2020-09-30_01_2020-12-18.xbrl : 158 / 330
# 当期純利益 875723000
# 総資産 7682001000
# 自己資本利益率 0.136
# 従業員数（人） 60
# 従業員数（人） 60
# 平均年齢（年） 37.1
# 平均勤続年数（年） 12.7
# 平均年間給与（円） 5129000
# 男性役員数（人） 6
# 女性役員数（人） 1
# EDINETコード E05360
# 業種 情報・通信業
# 企業名 日本ファルコム株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E01997-000_2020-09-30_01_2020-12-18.xbrl : 159 / 330
# 当期純利益 -13019000
# 総資産 6010736000
# 自己資本利益率 -0.004
# 従業員数（人） 192
# 臨時雇用者数 58
# 従業員数（人） 192
# 平均年齢（年） 44.3
# 平均勤続年数（年） 20.9
# 平均年間給与（円） 5708794
# 臨時雇用者数 58
# 従業員数（人） 192
# 臨時雇用者数 58
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E01997
# 業種 精密機器
# 企業名 助川電気工業株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00723-000_2020-09-30_01_2020-12-18.xbrl : 160 / 330
# 当期純利益 52956000
# 総資産 3923147000
# 自己資本利益率 0.015
# 従業員数（人） 77
# 臨時雇用者数 1
# 従業員数（人） 77
# 臨時雇用者数 1
# 平均年齢（年） 39
# 平均勤続年数（年） 13
# 平均年間給与（円） 6408060
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E00723
# 業種 情報・通信業
# 企業名 株式会社中央経済社ホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03343-000_2020-09-20_01_2020-12-18.xbrl : 161 / 330
# 当期純利益 1044000000
# 総資産 42612000000
# 自己資本利益率 0.074
# 従業員数（人） 716
# 臨時雇用者数 2662
# 従業員数（人） 716
# 臨時雇用者数 2662
# 平均年齢（年） 43.3
# 平均勤続年数（年） 10.8
# 平均年間給与（円） 5379442
# 男性役員数（人） 7
# 女性役員数（人） 1
# EDINETコード E03343
# 業種 小売業
# 企業名 株式会社ＰＬＡＮＴ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E30836-000_2020-09-30_01_2020-12-18.xbrl : 162 / 330
# 当期純利益 113815000
# 総資産 2528775000
# 自己資本利益率 0.108
# 従業員数（人） 119
# 従業員数（人） 119
# 平均年齢（年） 32.1
# 平均勤続年数（年） 3.9
# 平均年間給与（円） 6234000
# 従業員数（人） 119
# 男性役員数（人） 6
# 女性役員数（人）
# EDINETコード E30836
# 業種 サービス業
# 企業名 株式会社イルグルム
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04684-000_2020-09-30_01_2020-12-18.xbrl : 163 / 330
# 当期純利益 -23235000
# 総資産 3232038000
# 自己資本利益率
# 従業員数（人） 26
# 臨時雇用者数 66
# EDINETコード E04684
# 業種 サービス業
# 企業名 株式会社笠間ゴルフクラブ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03173-000_2020-09-30_01_2020-12-18.xbrl : 164 / 330
# 当期純利益 1822000000
# 総資産 54567000000
# 自己資本利益率 0.089
# 従業員数（人） 807
# 臨時雇用者数 2536
# 従業員数（人） 807
# 臨時雇用者数 2536
# 平均年齢（年） 40.5
# 平均勤続年数（年） 11.0
# 平均年間給与（円） 5513000
# 男性役員数（人） 11
# 女性役員数（人） 1
# EDINETコード E03173
# 業種 小売業
# 企業名 株式会社マミーマート
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00276-000_2020-09-30_01_2020-12-18.xbrl : 165 / 330
# 当期純利益 621212000
# 総資産 11246925000
# 自己資本利益率 0.096
# 従業員数（人） 224
# 臨時雇用者数 30
# 従業員数（人） 224
# 臨時雇用者数 30
# 平均年齢（年） 44
# 平均勤続年数（年） 14
# 平均年間給与（円） 4900369
# 従業員数（人） 224
# 臨時雇用者数 30
# 男性役員数（人） 10
# 女性役員数（人） 0
# EDINETコード E00276
# 業種 建設業
# 企業名 日本乾溜工業株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04038-000_2020-09-30_01_2020-12-18.xbrl : 166 / 330
# 当期純利益 416952000
# 総資産 54934958000
# 自己資本利益率 0.023
# 従業員数（人） 27
# 臨時雇用者数 2
# 従業員数（人） 27
# 臨時雇用者数 2
# 平均年齢（年） 47.9
# 平均勤続年数（年） 6.3
# 平均年間給与（円） 11728000
# 従業員数（人） 27
# 臨時雇用者数 2
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E04038
# 業種 不動産業
# 企業名 株式会社ランドビジネス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05196-000_2020-09-30_01_2020-12-18.xbrl : 167 / 330
# 当期純利益 120000000
# 総資産 46041000000
# 自己資本利益率 0.004
# 従業員数（人） 59
# 臨時雇用者数 1
# 従業員数（人） 59
# 臨時雇用者数 1
# 平均年齢（年） 53.0
# 平均勤続年数（年） 3.7
# 平均年間給与（円） 12533233
# 従業員数（人） 59
# 臨時雇用者数 1
# 男性役員数（人） 13
# 女性役員数（人） 1
# EDINETコード E05196
# 業種 サービス業
# 企業名 ＥＰＳホールディングス株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E03264-000_2020-09-30_01_2020-12-18.xbrl : 168 / 330
# 当期純利益 706201000
# 総資産 24540274000
# 自己資本利益率 0.0847
# 従業員数（人） 953
# 従業員数（人） 953
# 平均年齢（年） 44.2
# 平均勤続年数（年） 21.2
# 平均年間給与（円） 6742000
# 男性役員数（人） 6
# 女性役員数（人）
# EDINETコード E03264
# 業種 卸売業
# 企業名 扶桑電通株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E30996-000_2020-09-30_01_2020-12-18.xbrl : 169 / 330
# 当期純利益 292574000
# 総資産 4987796000
# 自己資本利益率 0.093
# 従業員数（人） 96
# 従業員数（人） 96
# 平均年齢（年） 37.5
# 平均勤続年数（年） 7.5
# 平均年間給与（円） 6428048
# 従業員数（人） 96
# 男性役員数（人） 9
# 女性役員数（人）
# EDINETコード E30996
# 業種 情報・通信業
# 企業名 株式会社ＣＲＩ・ミドルウェア
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E04275-000_2020-09-30_01_2020-12-18.xbrl : 170 / 330
# 当期純利益 1627478000
# 総資産 26206151000
# 自己資本利益率 0.128
# 従業員数（人） 1131
# 臨時雇用者数 392
# 従業員数（人） 1131
# 臨時雇用者数 392
# 平均年齢（年） 44
# 平均勤続年数（年） 14
# 平均年間給与（円） 6963225
# 男性役員数（人） 11
# 女性役員数（人） 1
# EDINETコード E04275
# 業種 空運業
# 企業名 アジア航測株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00975-000_2020-09-30_01_2020-12-18.xbrl : 171 / 330
# 当期純利益 2015000000
# 総資産 59288000000
# ...
# 自己資本利益率 0.028
# 従業員数（人） 176
# 臨時雇用者数 63
# 従業員数（人） 176
# 臨時雇用者数 63
# 平均年齢（年） 43.1
# 平均勤続年数（年） 12.5
# 平均年間給与（円） 6747000
# 男性役員数（人） 10
# 女性役員数（人）
# EDINETコード E02352
# 業種 精密機器
# 企業名 ＩＭＶ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00707-000_2020-09-30_01_2020-12-25.xbrl : 300 / 330
# 当期純利益 740000000
# 総資産 64809000000
# 自己資本利益率 0.025
# 従業員数（人） 41
# 臨時雇用者数 6
# 従業員数（人） 41
# 臨時雇用者数 6
# 平均年齢（年） 48.2
# 平均勤続年数（年） 20.7
# 平均年間給与（円） 9064662
# 従業員数（人） 41
# 臨時雇用者数 6
# 男性役員数（人） 14
# 女性役員数（人） 2
# EDINETコード E00707
# 業種 情報・通信業
# 企業名 株式会社学研ホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E22042-000_2020-09-30_01_2020-12-25.xbrl : 301 / 330
# 当期純利益 1212788000
# 総資産 17033137000
# 自己資本利益率 0.086
# 従業員数（人） 450
# 臨時雇用者数 18
# 従業員数（人） 450
# 平均年齢（年） 40.6
# 平均勤続年数（年） 14.0
# 平均年間給与（円） 5888000
# 臨時雇用者数 18
# 男性役員数（人） 7
# 女性役員数（人） 0
# EDINETコード E22042
# 業種 サービス業
# 企業名 株式会社シイエム・シイ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E33000-000_2020-09-30_01_2020-12-25.xbrl : 302 / 330
# 当期純利益 -415000000
# 総資産 78510000000
# 自己資本利益率
# 従業員数（人） 190
# 臨時雇用者数 13
# 従業員数（人） 190
# 臨時雇用者数 13
# 平均年齢（年） 40.3
# 平均勤続年数（年） 2.1
# 平均年間給与（円） 8121770
# 男性役員数（人） 6
# 女性役員数（人） 3
# EDINETコード E33000
# 業種 小売業
# 企業名 株式会社スシローグローバルホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E32620-000_2020-09-30_01_2020-12-25.xbrl : 303 / 330
# 当期純利益 234896000
# 総資産 9628832000
# 自己資本利益率 0.0370
# 従業員数（人） 102
# 臨時雇用者数 29
# 従業員数（人） 102
# 臨時雇用者数 29
# 平均年齢（年） 36.5
# 平均勤続年数（年） 4.4
# 平均年間給与（円） 6995169
# 男性役員数（人） 8
# 女性役員数（人） 1
# EDINETコード E32620
# 業種 情報・通信業
# 企業名 株式会社チェンジ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E32682-000_2020-09-30_01_2020-12-25.xbrl : 304 / 330
# 当期純利益 172221000
# 総資産 3631513000
# 自己資本利益率 0.068
# 従業員数（人） 88
# 臨時雇用者数
# 従業員数（人） 88
# 平均年齢（年） 38.9
# 平均勤続年数（年） 8.9
# 平均年間給与（円） 4797000
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E32682
# 業種 建設業
# 企業名 株式会社岐阜造園
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35150-000_2020-09-30_01_2020-12-25.xbrl : 305 / 330
# 当期純利益 381100000
# 総資産 4265498000
# 自己資本利益率 0.300
# 従業員数（人） 175
# 臨時雇用者数 13
# 従業員数（人） 175
# 臨時雇用者数 13
# 平均年齢（年） 35.4
# 平均勤続年数（年） 4.8
# 平均年間給与（円） 7047344000
# 従業員数（人） 175
# 臨時雇用者数 13
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E35150
# 業種 情報・通信業
# 企業名 HENNGE株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02449-000_2020-09-30_01_2020-12-25.xbrl : 306 / 330
# 当期純利益 55200000
# 総資産 3248347000
# 自己資本利益率 0.030
# 従業員数（人） 149
# 臨時雇用者数 112
# 従業員数（人） 149
# 平均年齢（年） 40.0
# 平均勤続年数（年） 11.0
# 平均年間給与（円） 4373000
# 従業員数（人） 149
# 男性役員数（人） 5
# 女性役員数（人） 1
# EDINETコード E02449
# 業種 その他製品
# 企業名 日本フォームサービス株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34973-000_2020-09-30_01_2020-12-25.xbrl : 307 / 330
# 当期純利益 -1207388000
# 総資産 3068993000
# 自己資本利益率
# 従業員数（人） 190
# 臨時雇用者数 24
# 従業員数（人） 190
# 臨時雇用者数 24
# 平均年齢（年） 33.0
# 平均勤続年数（年） 2.1
# 平均年間給与（円） 8871000
# 従業員数（人） 190
# 臨時雇用者数 24
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E34973
# 業種 情報・通信業
# 企業名 株式会社プレイド
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35258-000_2020-09-30_01_2020-12-25.xbrl : 308 / 330
# 当期純利益 228536000
# 総資産 1216818000
# 自己資本利益率 0.345
# 従業員数（人） 37
# 臨時雇用者数 3
# 従業員数（人） 37
# 臨時雇用者数 3
# 平均年齢（年） 36.8
# 平均勤続年数（年） 2.6
# 平均年間給与（円） 7745000
# 従業員数（人） 37
# 臨時雇用者数 3
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E35258
# 業種 サービス業
# 企業名 名南Ｍ＆Ａ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02971-000_2020-09-30_01_2020-12-25.xbrl : 309 / 330
# 当期純利益 829603000
# 総資産 8040833000
# 自己資本利益率 0.174
# 従業員数（人） 29
# 臨時雇用者数
# 従業員数（人） 29
# 平均年齢（年） 42.0
# 平均勤続年数（年） 6.8
# 平均年間給与（円） 4670000
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E02971
# 業種 卸売業
# 企業名 レカム株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34054-000_2020-09-30_01_2020-12-25.xbrl : 310 / 330
# 当期純利益 599000000
# 総資産 38526000000
# 自己資本利益率 0.019
# 従業員数（人） 719
# 臨時雇用者数 152
# 従業員数（人） 719
# 臨時雇用者数 152
# 平均年齢（年） 35.9
# 平均勤続年数（年） 3.9
# 平均年間給与（円） 4926000
# 従業員数（人） 719
# 臨時雇用者数 152
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E34054
# 業種 その他製品
# 企業名 株式会社ＭＴＧ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E26631-000_2020-09-30_01_2020-12-25.xbrl : 311 / 330
# 当期純利益 344073000
# 総資産 6384435000
# 自己資本利益率 0.131
# 従業員数（人） 125
# 臨時雇用者数 204
# 従業員数（人） 125
# 臨時雇用者数 204
# 平均年齢（年） 34.2
# 平均勤続年数（年） 3.58
# 平均年間給与（円） 4488000
# 従業員数（人） 125
# 臨時雇用者数 204
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E26631
# 業種 サービス業
# 企業名 株式会社アクトコール
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E27815-000_2020-09-30_01_2020-12-25.xbrl : 312 / 330
# 当期純利益 -168824000
# 総資産 4387292000
# 自己資本利益率
# 従業員数（人） 186
# 臨時雇用者数 55
# 従業員数（人） 186
# 臨時雇用者数 55
# 平均年齢（年） 36.9
# 平均勤続年数（年） 3.9
# 平均年間給与（円） 4887000
# 男性役員数（人） 6
# 女性役員数（人） 2
# EDINETコード E27815
# 業種 小売業
# 企業名 株式会社サンワカンパニー
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02075-000_2020-09-30_01_2020-12-28.xbrl : 313 / 330
# 当期純利益 -1059312000
# 総資産 2291813000
# 自己資本利益率
# 従業員数（人） 100
# 従業員数（人） 100
# 平均年齢（年） 45
# 平均勤続年数（年） 12
# 平均年間給与（円） 5161000
# 従業員数（人） 100
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E02075
# 業種 電気機器
# 企業名 株式会社ピクセラ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34256-000_2020-09-30_01_2020-12-28.xbrl : 314 / 330
# 当期純利益 385853000
# 総資産 8678552000
# 自己資本利益率 0.128
# 従業員数（人） 187
# 臨時雇用者数 57
# 従業員数（人） 187
# 臨時雇用者数 57
# 平均年齢（年） 37.3
# 平均勤続年数（年） 6.8
# 平均年間給与（円） 5491000
# 従業員数（人） 187
# 臨時雇用者数 57
# 男性役員数（人） 10
# 女性役員数（人） 0
# EDINETコード E34256
# 業種 不動産業
# 企業名 香陵住販株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02537-000_2020-09-30_01_2020-12-28.xbrl : 315 / 330
# 当期純利益 292634000
# 総資産 9770026000
# 自己資本利益率 0.154
# 従業員数（人） 113
# 臨時雇用者数 3
# EDINETコード E02537
# 業種 卸売業
# 企業名 株式会社日教販
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34954-000_2020-09-30_01_2020-12-28.xbrl : 316 / 330
# 当期純利益 253153000
# 総資産 3106896000
# 自己資本利益率 0.126
# 従業員数（人） 77
# 臨時雇用者数 22
# 従業員数（人） 77
# 臨時雇用者数 22
# 平均年齢（年） 31.0
# 平均勤続年数（年） 3.30
# 平均年間給与（円） 5113000
# 男性役員数（人） 9
# 女性役員数（人） 1
# EDINETコード E34954
# 業種 サービス業
# 企業名 株式会社ピアズ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02762-000_2020-09-30_01_2020-12-28.xbrl : 317 / 330
# 当期純利益 -391335000
# 総資産 7601671000
# 自己資本利益率
# 従業員数（人） 30
# 臨時雇用者数
# 従業員数（人） 30
# 平均年齢（年） 44
# 平均勤続年数（年） 16
# 平均年間給与（円） 6084000
# 従業員数（人） 30
# 男性役員数（人） 5
# 女性役員数（人） 1
# EDINETコード E02762
# 業種 卸売業
# 企業名 太洋物産株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34379-000_2020-09-30_01_2020-12-24.xbrl : 318 / 330
# 当期純利益 -324140000
# 総資産 3546459000
# 自己資本利益率
# 従業員数（人） 17
# 臨時雇用者数
# 従業員数（人） 17
# 平均年齢（年） 41.1
# 平均勤続年数（年） 15.7
# 平均年間給与（円） 5073000
# 男性役員数（人） 10
# 女性役員数（人） 0
# EDINETコード E34379
# 業種 サービス業
# 企業名 株式会社アクセスグループ・ホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E36129-000_2020-09-30_01_2020-12-28.xbrl : 319 / 330
# 当期純利益 -117831000
# 総資産 2350242000
# 自己資本利益率
# 従業員数（人） 9
# 従業員数（人） 9
# 平均年齢（年） 44.5
# 平均勤続年数（年） 3.3
# 平均年間給与（円） 4639000
# 男性役員数（人） 8
# 女性役員数（人）
# EDINETコード E36129
# 業種 医薬品
# 企業名 クリングルファーマ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E34819-000_2020-09-30_01_2020-12-28.xbrl : 320 / 330
# 当期純利益 -24080000
# 総資産 16441321000
# 自己資本利益率 -0.018
# 従業員数（人） 433
# 従業員数（人） 433
# 平均年齢（年） 30.0
# 平均勤続年数（年） 2.9
# 平均年間給与（円） 4511000
# 従業員数（人） 433
# 男性役員数（人） 6
# 女性役員数（人）
# EDINETコード E34819
# 業種 小売業
# 企業名 株式会社グッドスピード
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E33242-000_2020-09-30_01_2020-12-28.xbrl : 321 / 330
# 当期純利益 -708313000
# 総資産 4931472000
# 自己資本利益率
# 従業員数（人） 189
# 臨時雇用者数 156
# 従業員数（人） 189
# 臨時雇用者数 156
# 平均年齢（年） 30.1
# 平均勤続年数（年） 2.4
# 平均年間給与（円） 3770000
# 男性役員数（人） 6
# 女性役員数（人）
# EDINETコード E33242
# 業種 情報・通信業
# 企業名 シェアリングテクノロジー株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E00745-000_2020-09-30_01_2020-12-28.xbrl : 322 / 330
# 当期純利益 -2161188000
# 総資産 5613059000
# 自己資本利益率 -0.354
# 従業員数（人） 59
# 臨時雇用者数 3
# 従業員数（人） 59
# 臨時雇用者数 3
# 平均年齢（年） 37.8
# 平均勤続年数（年） 9
# 平均年間給与（円） 4136000
# 従業員数（人） 59
# 臨時雇用者数 3
# 男性役員数（人） 6
# 女性役員数（人） 0
# EDINETコード E00745
# 業種 その他金融業
# 企業名 株式会社ウェッジホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05181-000_2020-09-30_01_2020-12-28.xbrl : 323 / 330
# 当期純利益 330792000
# 総資産 25025499000
# 自己資本利益率 0.164
# 従業員数（人） 27
# 臨時雇用者数
# 従業員数（人） 27
# 臨時雇用者数
# 平均年齢（年） 34.4
# 平均勤続年数（年） 7.0
# 平均年間給与（円） 5050000
# 従業員数（人） 27
# 臨時雇用者数
# 男性役員数（人） 9
# 女性役員数（人） 2
# EDINETコード E05181
# 業種 情報・通信業
# 企業名 株式会社サカイホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E31019-000_2020-09-30_01_2020-12-28.xbrl : 324 / 330
# 当期純利益 -105172000
# 総資産 5038643000
# 自己資本利益率
# 従業員数（人） 162
# 臨時雇用者数 20
# 従業員数（人） 162
# 臨時雇用者数 20
# 平均年齢（年） 32.2
# 平均勤続年数（年） 2.5
# 平均年間給与（円） 5631000
# 従業員数（人） 162
# 臨時雇用者数 20
# 男性役員数（人） 11
# 女性役員数（人） 1
# EDINETコード E31019
# 業種 情報・通信業
# 企業名 株式会社クラウドワークス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E36002-000_2020-09-30_01_2020-12-28.xbrl : 325 / 330
# 当期純利益 245498000
# 総資産 3084602000
# 自己資本利益率 0.096
# 従業員数（人） 127
# 従業員数（人） 127
# 平均年齢（年） 33.4
# 平均勤続年数（年） 7.2
# 平均年間給与（円） 4073000
# 男性役員数（人） 5
# 女性役員数（人）
# EDINETコード E36002
# 業種 情報・通信業
# 企業名 東和ハイシステム株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05633-000_2020-09-30_01_2020-12-28.xbrl : 326 / 330
# 当期純利益 -655473000
# 総資産 2183122000
# 自己資本利益率
# 従業員数（人） 113
# 臨時雇用者数 31
# 従業員数（人） 113
# 臨時雇用者数 31
# 平均年齢（年） 38.8
# 平均勤続年数（年） 8.7
# 平均年間給与（円） 4148688
# 従業員数（人） 113
# 臨時雇用者数 31
# 男性役員数（人） 7
# 女性役員数（人） 1
# EDINETコード E05633
# 業種 情報・通信業
# 企業名 株式会社アルファクス・フード・システム
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E02982-000_2020-09-30_01_2020-12-28.xbrl : 327 / 330
# 当期純利益 85171000
# 総資産 3968148000
# 自己資本利益率 0.0391
# 従業員数（人） 32
# 臨時雇用者数 73
# 従業員数（人） 32
# 臨時雇用者数 73
# 平均年齢（年） 41.0
# 平均勤続年数（年） 8.6
# 平均年間給与（円） 5563431
# 男性役員数（人） 8
# 女性役員数（人） 2
# EDINETコード E02982
# 業種 卸売業
# 企業名 株式会社ｃｏｔｔａ
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05174-000_2020-09-30_01_2020-12-28.xbrl : 328 / 330
# 当期純利益 811000000
# 総資産 36672000000
# 自己資本利益率 0.063
# 従業員数（人） 50
# 臨時雇用者数 2
# 従業員数（人） 50
# 臨時雇用者数 2
# 平均年齢（年） 39.25
# 平均勤続年数（年） 8.86
# 平均年間給与（円） 5358589
# 男性役員数（人） 7
# 女性役員数（人） 0
# EDINETコード E05174
# 業種 不動産業
# 企業名 ＡＰＡＭＡＮ株式会社
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E35140-000_2020-09-30_01_2020-12-28.xbrl : 329 / 330
# 当期純利益 236247000
# 総資産 9348348000
# 自己資本利益率 0.136
# 従業員数（人） 43
# 臨時雇用者数 1
# 従業員数（人） 43
# 臨時雇用者数 1
# 平均年齢（年） 36.5
# 平均勤続年数（年） 2.3
# 平均年間給与（円） 6674000
# 男性役員数（人） 7
# 女性役員数（人）
# EDINETコード E35140
# 業種 サービス業
# 企業名 株式会社アンビスホールディングス
#
# /content/drive/MyDrive/Graduation Paper Data/20201001-20201231/XBRL/PublicDoc/jpcrp030000-asr-001_E05336-000_2020-09-30_01_2020-12-28.xbrl : 330 / 330
# 当期純利益 80662000
# 総資産 5008902000
# 自己資本利益率 0.018
# 従業員数（人） 149
# 臨時雇用者数 37
# 従業員数（人） 149
# 臨時雇用者数 37
# 平均年齢（年） 39.4
# 平均勤続年数（年） 9.9
# 平均年間給与（円） 5113971
# 従業員数（人） 149
# 臨時雇用者数 37
# 男性役員数（人） 8
# 女性役員数（人） 1
# EDINETコード E05336
# 業種 情報・通信業
# 企業名 ジョルダン株式会社
#
# [['E02515', '株式会社内田洋行', '卸売業', '1943000000', '0.085', '72853000000', '0', '12', '203', '7285955', '19.0', '42.9', '1077'], ['E01874', 'サクサホールディングス株式会社', '電気機器', '592000000', '0.029', '24094000000', '1', '7', '', '9135000', '5', '52', '26'], ['E05006', 'ウチダエスコ株式会社', 'サービス業', '1066214000', '0.183', '13321214000', '0', '12', '80', '6219151', '17', '43', '552'], ['E02060', 'サムコ 株式会社', '機械', '634740000', '0.074', '11274375000', '', '10', '4', '6166340', '14.0', '40.0', '171'], ['E05378', '株式会社プラネット', 'サービス業', '441723000', '0.099', '5314042000', '0', '11', '8', '9773364', '14.0', '45.1', '44'], ['E32254', '株式会社ＪＭホールディングス', '小売業', '249000000', '0.016', '16331000000', '2', '11', '8', '4577000', '4.1', '38.3', '43'], ['E02484', '株式会社ファーマフーズ', '食料品', '579970000', '0.1306', '9796358000', '1', '10', '21', '5597569', '4.7', '38.3', '76'], ['E30699', '株式会社鳥貴族', '小売業', '-763329000', '-0.125', '19953267000', '', '10', '2599', '4595000', '4.7', '33.4', '854'], ['E05161', '株式会社メディアシーク', '情報・通信業', '69126000', '0.023', '4553050000', '1', '8', '1', '4305000', '6.0', '32.9', '81'], ['E04696', '株式会社\u3000藤ケ谷カントリー倶楽部', 'サービス業', '-26310000', '-0.015', '2511597000', '', '', '48', '', '', '', '54'], ['E31408', '日本スキー場開発株式会社', 'サービス業', '143335000', '0.053', '3835774000', '1', '10', '0', '6568000', '3.3', '42.5', '39'], ['E31248', '株式会社ファーストロジック', 'サービス業', '569201000', '0.164', '3942590000', '0', '6', '6', '5553889', '4.1', '30.2', '55'], ['E01451', '株式会社稲葉製作所', '金属製品', '1287688000', '0.034', '50676644000', '', '13', '', '5638248', '18', '41', '888'], ['E33313', '株式会社クロスフォー', 'その他製品', '-616361000', '-0.272', '5219145000', '', '9', '11', '3752000', '4.8', '35.6', '94'], ['E02469', 'ゼネラルパッカー株式会社', '機械', '614210000', '0.139', '8384797000', '', '9', '37', '5848204', '13.1', '37.9', '158'], ['E26322', 'ティーライフ株式会社', '小売業', '185727000', '0.041', '6714188000', '1', '8', '57', '4693000', '9.6', '35.4', '104'], ['E32687', '株式会社アイモバイル', 'サービス業', '1538993000', '0.119', '14964797000', '0', '9', '', '5564000', '3.82', '31.33', '215'], ['E05635', '株式会社大和コンピューター', '情報・通信業', '281753000', '0.075', '4761826000', '', '7', '', '5770886', '16.8', '40.1', '174'], ['E00735', '総合商研株式会社', 'その他製品', '-171061000', '-0.079', '9399142000', '1', '11', '158', '4107000', '11.1', '43.2', '366'], ['E35004', '株式会社ブシロード', 'その他製品', '734627000', '0.021', '27653424000', '', '9', '49', '4677219', '3.3', '32.1', '237'], ['E30042', '株式会社ウエスコホールディングス', 'サービス業', '319020000', '0.0277', '11654042000', '', '7', '3', '6261446', '12.0', '46.0', '15'], ['E00239', '株式会社大盛工業', '建設業', '259157000', '0.066', '8853019000', '', '8', '', '7100578', '10.5', '40.3', '61'], ['E31441', '株式会社シーアールイー', '不動産業', '1870746000', '0.105', '66445517000', '', '11', '', '6295000', '9.0', '40.2', '169'], ['E33282', '株式会社シルバーライフ', '卸売業', '678562000', '0.1688', '5613946000', '', '9', '122', '4386000', '3.5', '35.4', '101'], ['E26369', '株式会社エイチーム', '情報・通信業', '-559000000', '', '13667000000', '', '8', '14', '5047763', '4.8', '32.0', '468'], ['E33948', '株式会社ベストワンドットコム', 'サービス業', '-52879000', '-0.0762', '2626731000', '1', '8', '7', '3295000', '2.7', '30.0', '26'], ['E33966', 'ラクスル株式会社', '情報・通信業', '-494135000', '', '19379817000', '2', '9', '19', '5562416', '2.2', '34.0', '304'], ['E33910', '株式会社ニッソウ', '建設業', '124776000', '0.141', '1133552000', '', '10', '', '5892000', '4.9', '40.7', '45'], ['E34114', 'ＶＡＬＵＥＮＥＸ株式会社', '情報・通信業', '-62617000', '', '999427000', '', '10', '7', '7387691', '1.8', '36.7', '28'], ['E05357', 'ジャパンメディアシステム株式会社', 'サービス業', '422331000', '0.5608', '2046185000', '', '', '3', '', '', '', '114'], ['E02121', '株式会社\u3000山王', '金属製品', '158690000', '0.039', '9963376000', '', '8', '18', '4526384', '14.2', '41.4', '275'], ['E35932', '株式会社アースインフィニティ', '小売業', '374737000', '0.751', '1460914000', '1', '5', '', '4317000', '4.0', '34.2', '46'], ['E03212', '株式会社一や', '小売業', '34688000', '0.0150', '2514870000', '', '', '45', '', '', '', '19'], ['E05705', '株式会社アイル', '情報・通信業', '1155812000', '0.365', '7293139000', '', '11', '', '5778067', '7.5 ...
#     EDINETCODE                  企業名      業種  ...  平均勤続年数（年） 平均年齢（歳） 従業員数（人）
# 0       E02515             株式会社内田洋行     卸売業  ...       19.0    42.9    1077
# 1       E01874      サクサホールディングス株式会社    電気機器  ...          5      52      26
# 2       E05006           ウチダエスコ株式会社   サービス業  ...         17      43     552
# 3       E02060             サムコ 株式会社      機械  ...       14.0    40.0     171
# 4       E05378            株式会社プラネット   サービス業  ...       14.0    45.1      44
# ..         ...                  ...     ...  ...        ...     ...     ...
# 325     E05633  株式会社アルファクス・フード・システム  情報・通信業  ...        8.7    38.8     113
# 326     E02982            株式会社ｃｏｔｔａ     卸売業  ...        8.6    41.0      32
# 327     E05174           ＡＰＡＭＡＮ株式会社    不動産業  ...       8.86   39.25      50
# 328     E35140     株式会社アンビスホールディングス   サービス業  ...        2.3    36.5      43
# 329     E05336            ジョルダン株式会社  情報・通信業  ...        9.9    39.4     149
#
# [330 rows x 13 columns]
# extract finish
